# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 강수량과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlwo를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/강수량,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 1hr 최대 강수량(mm)      537
# 일평균 강수량(mm)         537
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 1hr 최대 강수량(mm)      0
# 일평균 강수량(mm)         0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  156.21307
# - 하수관로비율(MAX):  [0.77204263]
# # 500  손실 비용:  22.756947
# - 하수관로비율(MAX):  [0.7685183]
# # 1000  손실 비용:  19.176231
# - 하수관로비율(MAX):  [0.7700976]
# # 1500  손실 비용:  16.263376
# - 하수관로비율(MAX):  [0.7715114]
# # 2000  손실 비용:  13.812899
# - 하수관로비율(MAX):  [0.7726282]
# # 2500  손실 비용:  11.751276
# - 하수관로비율(MAX):  [0.77346873]
# # 3000  손실 비용:  10.01675
# - 하수관로비율(MAX):  [0.7740569]
# # 3500  손실 비용:  8.557382
# - 하수관로비율(MAX):  [0.7744142]
# # 4000  손실 비용:  7.329469
# - 하수관로비율(MAX):  [0.7745605]
# # 4500  손실 비용:  6.2962537
# - 하수관로비율(MAX):  [0.7745139]
# # 5000  손실 비용:  5.4268227
# - 하수관로비율(MAX):  [0.77429104]
# # 5500  손실 비용:  4.695158
# - 하수관로비율(MAX):  [0.7739079]
# # 6000  손실 비용:  4.079387
# - 하수관로비율(MAX):  [0.7733774]
# # 6500  손실 비용:  3.5611062
# - 하수관로비율(MAX):  [0.7727141]
# # 7000  손실 비용:  3.124831
# - 하수관로비율(MAX):  [0.771928]
# # 7500  손실 비용:  2.75754
# - 하수관로비율(MAX):  [0.77103096]
# # 8000  손실 비용:  2.4482856
# - 하수관로비율(MAX):  [0.7700329]
# # 8500  손실 비용:  2.1878493
# - 하수관로비율(MAX):  [0.76894283]
# # 9000  손실 비용:  1.9684818
# - 하수관로비율(MAX):  [0.76776963]
# # 9500  손실 비용:  1.7836602
# - 하수관로비율(MAX):  [0.7665195]
# # 10000  손실 비용:  1.6279024
# - 하수관로비율(MAX):  [0.76520145]
# # 10500  손실 비용:  1.4965936
# - 하수관로비율(MAX):  [0.7638203]
# # 11000  손실 비용:  1.3858539
# - 하수관로비율(MAX):  [0.76238173]
# # 11500  손실 비용:  1.2924192
# - 하수관로비율(MAX):  [0.76089287]
# # 12000  손실 비용:  1.2135434
# - 하수관로비율(MAX):  [0.7593576]
# # 12500  손실 비용:  1.146917
# - 하수관로비율(MAX):  [0.7577819]
# # 13000  손실 비용:  1.0905952
# - 하수관로비율(MAX):  [0.7561657]
# # 13500  손실 비용:  1.0429447
# - 하수관로비율(MAX):  [0.75451684]
# # 14000  손실 비용:  1.0025913
# - 하수관로비율(MAX):  [0.7528383]
# # 14500  손실 비용:  0.9683786
# - 하수관로비율(MAX):  [0.751134]
# # 15000  손실 비용:  0.9393329
# - 하수관로비율(MAX):  [0.74940544]
# # 15500  손실 비용:  0.9146328
# - 하수관로비율(MAX):  [0.7476506]
# # 16000  손실 비용:  0.8935964
# - 하수관로비율(MAX):  [0.74588245]
# # 16500  손실 비용:  0.87563914
# - 하수관로비율(MAX):  [0.7440943]
# # 17000  손실 비용:  0.8602775
# - 하수관로비율(MAX):  [0.7422946]
# # 17500  손실 비용:  0.84709644
# - 하수관로비율(MAX):  [0.74047667]
# # 18000  손실 비용:  0.83576256
# - 하수관로비율(MAX):  [0.7386587]
# # 18500  손실 비용:  0.82596964
# - 하수관로비율(MAX):  [0.73681974]
# # 19000  손실 비용:  0.81748134
# - 하수관로비율(MAX):  [0.734972]
# # 19500  손실 비용:  0.81009823
# - 하수관로비율(MAX):  [0.73312426]
# # 20000  손실 비용:  0.80364656
# - 하수관로비율(MAX):  [0.7312765]
# # 20500  손실 비용:  0.7979804
# - 하수관로비율(MAX):  [0.72942877]
# # 21000  손실 비용:  0.7929693
# - 하수관로비율(MAX):  [0.7275706]
# # 21500  손실 비용:  0.7885024
# - 하수관로비율(MAX):  [0.72569305]
# # 22000  손실 비용:  0.78450745
# - 하수관로비율(MAX):  [0.7238155]
# # 22500  손실 비용:  0.7809111
# - 하수관로비율(MAX):  [0.72193795]
# # 23000  손실 비용:  0.77765113
# - 하수관로비율(MAX):  [0.7200604]
# # 23500  손실 비용:  0.7746762
# - 하수관로비율(MAX):  [0.71818286]
# # 24000  손실 비용:  0.771942
# - 하수관로비율(MAX):  [0.7163053]
# # 24500  손실 비용:  0.7694221
# - 하수관로비율(MAX):  [0.7144416]
# # 25000  손실 비용:  0.7670875
# - 하수관로비율(MAX):  [0.71259385]
# # 25500  손실 비용:  0.7648994
# - 하수관로비율(MAX):  [0.7107461]
# # 26000  손실 비용:  0.76283604
# - 하수관로비율(MAX):  [0.70889837]
# # 26500  손실 비용:  0.76087874
# - 하수관로비율(MAX):  [0.7070506]
# # 27000  손실 비용:  0.759012
# - 하수관로비율(MAX):  [0.7052029]
# # 27500  손실 비용:  0.75722235
# - 하수관로비율(MAX):  [0.70335513]
# # 28000  손실 비용:  0.755499
# - 하수관로비율(MAX):  [0.7015074]
# # 28500  손실 비용:  0.75383794
# - 하수관로비율(MAX):  [0.6996674]
# # 29000  손실 비용:  0.7522419
# - 하수관로비율(MAX):  [0.69784945]
# # 29500  손실 비용:  0.7506878
# - 하수관로비율(MAX):  [0.6960315]
# # 30000  손실 비용:  0.7491702
# - 하수관로비율(MAX):  [0.69421357]
# # 30500  손실 비용:  0.7476841
# - 하수관로비율(MAX):  [0.6923956]
# # 31000  손실 비용:  0.7462259
# - 하수관로비율(MAX):  [0.6905777]
# # 31500  손실 비용:  0.74480736
# - 하수관로비율(MAX):  [0.68878144]
# # 32000  손실 비용:  0.7434158
# - 하수관로비율(MAX):  [0.6869933]
# # 32500  손실 비용:  0.7420433
# - 하수관로비율(MAX):  [0.68520516]
# # 33000  손실 비용:  0.74068767
# - 하수관로비율(MAX):  [0.683417]
# # 33500  손실 비용:  0.73934686
# - 하수관로비율(MAX):  [0.6816289]
# # 34000  손실 비용:  0.7380374
# - 하수관로비율(MAX):  [0.6798655]
# # 34500  손실 비용:  0.7367435
# - 하수관로비율(MAX):  [0.67810714]
# # 35000  손실 비용:  0.7354609
# - 하수관로비율(MAX):  [0.6763488]
# # 35500  손실 비용:  0.7341884
# - 하수관로비율(MAX):  [0.67459047]
# # 36000  손실 비용:  0.7329299
# - 하수관로비율(MAX):  [0.6728383]
# # 36500  손실 비용:  0.7316966
# - 하수관로비율(MAX):  [0.67110974]
# # 37000  손실 비용:  0.7304716
# - 하수관로비율(MAX):  [0.6693812]
# # 37500  손실 비용:  0.7292541
# - 하수관로비율(MAX):  [0.66765267]
# # 38000  손실 비용:  0.7280442
# - 하수관로비율(MAX):  [0.66592413]
# # 38500  손실 비용:  0.7268557
# - 하수관로비율(MAX):  [0.6642168]
# # 39000  손실 비용:  0.7256797
# - 하수관로비율(MAX):  [0.6625181]
# # 39500  손실 비용:  0.7245099
# - 하수관로비율(MAX):  [0.66081935]
# # 40000  손실 비용:  0.72334623
# - 하수관로비율(MAX):  [0.6591206]
# # 40500  손실 비용:  0.72219396
# - 하수관로비율(MAX):  [0.65742993]
# # 41000  손실 비용:  0.72106206
# - 하수관로비율(MAX):  [0.655761]
# # 41500  손실 비용:  0.71993566
# - 하수관로비율(MAX):  [0.6540921]
# # 42000  손실 비용:  0.71881455
# - 하수관로비율(MAX):  [0.65242314]
# # 42500  손실 비용:  0.71769893
# - 하수관로비율(MAX):  [0.6507542]
# # 43000  손실 비용:  0.7166049
# - 하수관로비율(MAX):  [0.64911026]
# # 43500  손실 비용:  0.7155192
# - 하수관로비율(MAX):  [0.64747113]
# # 44000  손실 비용:  0.71443826
# - 하수관로비율(MAX):  [0.645832]
# # 44500  손실 비용:  0.7133622
# - 하수관로비율(MAX):  [0.6441929]
# # 45000  손실 비용:  0.71229845
# - 하수관로비율(MAX):  [0.64256525]
# # 45500  손실 비용:  0.71125126
# - 하수관로비율(MAX):  [0.6409559]
# # 46000  손실 비용:  0.71020865
# - 하수관로비율(MAX):  [0.6393466]
# # 46500  손실 비용:  0.70917076
# - 하수관로비율(MAX):  [0.6377373]
# # 47000  손실 비용:  0.7081373
# - 하수관로비율(MAX):  [0.63612795]
# # 47500  손실 비용:  0.70712525
# - 하수관로비율(MAX):  [0.6345452]
# # 48000  손실 비용:  0.70611966
# - 하수관로비율(MAX):  [0.6329657]
# # 48500  손실 비용:  0.7051185
# - 하수관로비율(MAX):  [0.63138616]
# # 49000  손실 비용:  0.7041214
# - 하수관로비율(MAX):  [0.62980664]
# # 49500  손실 비용:  0.7031353
# - 하수관로비율(MAX):  [0.62823737]
# # 50000  손실 비용:  0.7021655
# - 하수관로비율(MAX):  [0.62668765]
# # 50500  손실 비용:  0.70119953
# - 하수관로비율(MAX):  [0.6251379]
# # 51000  손실 비용:  0.7002381
# - 하수관로비율(MAX):  [0.6235882]
# # 51500  손실 비용:  0.69928086
# - 하수관로비율(MAX):  [0.6220385]
# # 52000  손실 비용:  0.69834065
# - 하수관로비율(MAX):  [0.62051046]
# # 52500  손실 비용:  0.6974096
# - 하수관로비율(MAX):  [0.61899054]
# # 53000  손실 비용:  0.6964824
# - 하수관로비율(MAX):  [0.6174706]
# # 53500  손실 비용:  0.6955593
# - 하수관로비율(MAX):  [0.6159507]
# # 54000  손실 비용:  0.6946405
# - 하수관로비율(MAX):  [0.61443186]
# # 54500  손실 비용:  0.693743
# - 하수관로비율(MAX):  [0.61294174]
# # 55000  손실 비용:  0.6928493
# - 하수관로비율(MAX):  [0.6114516]
# # 55500  손실 비용:  0.6919593
# - 하수관로비율(MAX):  [0.6099615]
# # 56000  손실 비용:  0.6910732
# - 하수관로비율(MAX):  [0.6084714]
# # 56500  손실 비용:  0.6901953
# - 하수관로비율(MAX):  [0.606989]
# # 57000  손실 비용:  0.68933415
# - 하수관로비율(MAX):  [0.6055287]
# # 57500  손실 비용:  0.68847674
# - 하수관로비율(MAX):  [0.6040684]
# # 58000  손실 비용:  0.68762267
# - 하수관로비율(MAX):  [0.6026081]
# # 58500  손실 비용:  0.68677235
# - 하수관로비율(MAX):  [0.6011478]
# # 59000  손실 비용:  0.6859326
# - 하수관로비율(MAX):  [0.5996992]
# # 59500  손실 비용:  0.6851066
# - 하수관로비율(MAX):  [0.5982687]
# # 60000  손실 비용:  0.68428415
# - 하수관로비율(MAX):  [0.5968382]
# # 60500  손실 비용:  0.68346506
# - 하수관로비율(MAX):  [0.59540766]
# # 61000  손실 비용:  0.6826495
# - 하수관로비율(MAX):  [0.59397715]
# # 61500  손실 비용:  0.68184465
# - 하수관로비율(MAX):  [0.5925595]
# # 62000  손실 비용:  0.68105274
# - 하수관로비율(MAX):  [0.5911588]
# # 62500  손실 비용:  0.68026423
# - 하수관로비율(MAX):  [0.5897581]
# # 63000  손실 비용:  0.67947906
# - 하수관로비율(MAX):  [0.5883574]
# # 63500  손실 비용:  0.678697
# - 하수관로비율(MAX):  [0.5869567]
# # 64000  손실 비용:  0.6779245
# - 하수관로비율(MAX):  [0.58556694]
# # 64500  손실 비용:  0.6771657
# - 하수관로비율(MAX):  [0.58419603]
# # 65000  손실 비용:  0.67641
# - 하수관로비율(MAX):  [0.5828251]
# # 65500  손실 비용:  0.6756574
# - 하수관로비율(MAX):  [0.5814542]
# # 66000  손실 비용:  0.6749081
# - 하수관로비율(MAX):  [0.5800833]
# # 66500  손실 비용:  0.67416507
# - 하수관로비율(MAX):  [0.57871825]
# # 67000  손실 비용:  0.67343813
# - 하수관로비율(MAX):  [0.57737714]
# # 67500  손실 비용:  0.6727142
# - 하수관로비율(MAX):  [0.57603604]
# # 68000  손실 비용:  0.67199343
# - 하수관로비율(MAX):  [0.57469493]
# # 68500  손실 비용:  0.6712757
# - 하수관로비율(MAX):  [0.5733538]
# # 69000  손실 비용:  0.67056084
# - 하수관로비율(MAX):  [0.5720127]
# # 69500  손실 비용:  0.66986346
# - 하수관로비율(MAX):  [0.57069874]
# # 70000  손실 비용:  0.6691705
# - 하수관로비율(MAX):  [0.56938744]
# # 70500  손실 비용:  0.6684802
# - 하수관로비율(MAX):  [0.56807613]
# # 71000  손실 비용:  0.667793
# - 하수관로비율(MAX):  [0.56676483]
# # 71500  손실 비용:  0.6671087
# - 하수관로비율(MAX):  [0.5654535]
# # 72000  손실 비용:  0.666435
# - 하수관로비율(MAX):  [0.5641573]
# # 72500  손실 비용:  0.6657719
# - 하수관로비율(MAX):  [0.5628758]
# # 73000  손실 비용:  0.6651114
# - 하수관로비율(MAX):  [0.5615943]
# # 73500  손실 비용:  0.66445386
# - 하수관로비율(MAX):  [0.5603128]
# # 74000  손실 비용:  0.66379887
# - 하수관로비율(MAX):  [0.5590313]
# # 74500  손실 비용:  0.6631468
# - 하수관로비율(MAX):  [0.5577498]
# # 75000  손실 비용:  0.6625122
# - 하수관로비율(MAX):  [0.5564974]
# # 75500  손실 비용:  0.6618806
# - 하수관로비율(MAX):  [0.5552457]
# # 76000  손실 비용:  0.6612514
# - 하수관로비율(MAX):  [0.553994]
# # 76500  손실 비용:  0.6606253
# - 하수관로비율(MAX):  [0.5527423]
# # 77000  손실 비용:  0.6600015
# - 하수관로비율(MAX):  [0.5514906]
# # 77500  손실 비용:  0.6593852
# - 하수관로비율(MAX):  [0.5502483]
# # 78000  손실 비용:  0.65878135
# - 하수관로비율(MAX):  [0.5490264]
# # 78500  손실 비용:  0.6581802
# - 하수관로비율(MAX):  [0.54780453]
# # 79000  손실 비용:  0.6575815
# - 하수관로비율(MAX):  [0.54658264]
# # 79500  손실 비용:  0.6569853
# - 하수관로비율(MAX):  [0.54536074]
# # 80000  손실 비용:  0.6563917
# - 하수관로비율(MAX):  [0.54413885]
# # 80500  손실 비용:  0.65580785
# - 하수관로비율(MAX):  [0.5429324]
# # 81000  손실 비용:  0.6552336
# - 하수관로비율(MAX):  [0.5417403]
# # 81500  손실 비용:  0.6546618
# - 하수관로비율(MAX):  [0.5405482]
# # 82000  손실 비용:  0.6540921
# - 하수관로비율(MAX):  [0.5393561]
# # 82500  손실 비용:  0.653525
# - 하수관로비율(MAX):  [0.538164]
# # 83000  손실 비용:  0.6529602
# - 하수관로비율(MAX):  [0.5369719]
# # 83500  손실 비용:  0.6524059
# - 하수관로비율(MAX):  [0.53579694]
# # 84000  손실 비용:  0.65185994
# - 하수관로비율(MAX):  [0.53463465]
# # 84500  손실 비용:  0.65131617
# - 하수관로비율(MAX):  [0.53347236]
# # 85000  손실 비용:  0.65077466
# - 하수관로비율(MAX):  [0.53231007]
# # 85500  손실 비용:  0.65023553
# - 하수관로비율(MAX):  [0.5311478]
# # 86000  손실 비용:  0.6496986
# - 하수관로비율(MAX):  [0.5299855]
# # 86500  손실 비용:  0.6491706
# - 하수관로비율(MAX):  [0.52883744]
# # 87000  손실 비용:  0.6486517
# - 하수관로비율(MAX):  [0.52770495]
# # 87500  손실 비용:  0.6481351
# - 하수관로비율(MAX):  [0.52657247]
# # 88000  손실 비용:  0.64762074
# - 하수관로비율(MAX):  [0.52544]
# # 88500  손실 비용:  0.6471084
# - 하수관로비율(MAX):  [0.5243075]
# # 89000  손실 비용:  0.64659834
# - 하수관로비율(MAX):  [0.523175]
# # 89500  손실 비용:  0.64609337
# - 하수관로비율(MAX):  [0.5220492]
# # 90000  손실 비용:  0.64560086
# - 하수관로비율(MAX):  [0.5209465]
# # 90500  손실 비용:  0.64511037
# - 하수관로비율(MAX):  [0.5198438]
# # 91000  손실 비용:  0.6446219
# - 하수관로비율(MAX):  [0.51874113]
# # 91500  손실 비용:  0.6441357
# - 하수관로비율(MAX):  [0.51763844]
# # 92000  손실 비용:  0.6436513
# - 하수관로비율(MAX):  [0.51653576]
# # 92500  손실 비용:  0.6431691
# - 하수관로비율(MAX):  [0.5154331]
# # 93000  손실 비용:  0.6426992
# - 하수관로비율(MAX):  [0.51435417]
# # 93500  손실 비용:  0.6422338
# - 하수관로비율(MAX):  [0.5132813]
# # 94000  손실 비용:  0.64177066
# - 하수관로비율(MAX):  [0.5122084]
# # 94500  손실 비용:  0.6413091
# - 하수관로비율(MAX):  [0.5111355]
# # 95000  손실 비용:  0.6408497
# - 하수관로비율(MAX):  [0.51006263]
# # 95500  손실 비용:  0.64039207
# - 하수관로비율(MAX):  [0.50898975]
# # 96000  손실 비용:  0.639939
# - 하수관로비율(MAX):  [0.5079227]
# # 96500  손실 비용:  0.6394979
# - 하수관로비율(MAX):  [0.5068796]
# # 97000  손실 비용:  0.63905865
# - 하수관로비율(MAX):  [0.50583655]
# # 97500  손실 비용:  0.6386212
# - 하수관로비율(MAX):  [0.50479347]
# # 98000  손실 비용:  0.63818556
# - 하수관로비율(MAX):  [0.5037504]
# # 98500  손실 비용:  0.63775194
# - 하수관로비율(MAX):  [0.5027073]
# # 99000  손실 비용:  0.63732004
# - 하수관로비율(MAX):  [0.5016642]
# # 99500  손실 비용:  0.63689494
# - 하수관로비율(MAX):  [0.5006332]
# # 100000  손실 비용:  0.63647634
# - 하수관로비율(MAX):  [0.4996143]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
import tensorflow.compat.v1 as tf
import numpy as np

# 모델 불러오기
sess = tf.Session()
save_path = "./saved.cpkt"
saver = tf.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.get_default_graph()
X = graph.get_tensor_by_name("X:0")
hypothesis = graph.get_tensor_by_name("add:0")

# %%
# 사용자로부터 강수량을 입력받습니다.

onehr_rain_fall = float(input('1hr 최대 강수량(mm): '))
day_rain_fall = float(input('일평균 강수량(mm): '))
# Out:
# 1hr 최대 강수량(mm): 8
# 일평균 강수량(mm): 26

# %%
# 입력 데이터 준비
data = np.array([[onehr_rain_fall, day_rain_fall]], dtype=np.float32)

# 예측 수행
feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.57478476
