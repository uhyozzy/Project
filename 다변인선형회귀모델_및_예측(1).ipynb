# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 강수량과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlow를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/강수량,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 1hr 최대 강수량(mm)        0
# 일평균 강수량(mm)           0
# [MAX] 하수관로 비율(%)    151
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 1hr 최대 강수량(mm)      0
# 일평균 강수량(mm)         0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  1.0670772
# - 하수관로비율(MAX):  [-0.30555063]
# # 500  손실 비용:  1.0660578
# - 하수관로비율(MAX):  [-0.3038993]
# # 1000  손실 비용:  1.0650567
# - 하수관로비율(MAX):  [-0.3022634]
# # 1500  손실 비용:  1.0640687
# - 하수관로비율(MAX):  [-0.30063602]
# # 2000  손실 비용:  1.0630969
# - 하수관로비율(MAX):  [-0.29901978]
# # 2500  손실 비용:  1.0621393
# - 하수관로비율(MAX):  [-0.29741606]
# # 3000  손실 비용:  1.0611963
# - 하수관로비율(MAX):  [-0.29582208]
# # 3500  손실 비용:  1.0602676
# - 하수관로비율(MAX):  [-0.2942388]
# # 4000  손실 비용:  1.0593529
# - 하수관로비율(MAX):  [-0.29266715]
# # 4500  손실 비용:  1.058452
# - 하수관로비율(MAX):  [-0.29110506]
# # 5000  손실 비용:  1.0575643
# - 하수관로비율(MAX):  [-0.28955424]
# # 5500  손실 비용:  1.0566908
# - 하수관로비율(MAX):  [-0.28801453]
# # 6000  손실 비용:  1.0558288
# - 하수관로비율(MAX):  [-0.28648278]
# # 6500  손실 비용:  1.054982
# - 하수관로비율(MAX):  [-0.2849651]
# # 7000  손실 비용:  1.0541457
# - 하수관로비율(MAX):  [-0.28345427]
# # 7500  손실 비용:  1.0533237
# - 하수관로비율(MAX):  [-0.28195617]
# # 8000  손실 비용:  1.0525124
# - 하수관로비율(MAX):  [-0.2804667]
# # 8500  손실 비용:  1.0517143
# - 하수관로비율(MAX):  [-0.27898723]
# # 9000  손실 비용:  1.0509276
# - 하수관로비율(MAX):  [-0.27751893]
# # 9500  손실 비용:  1.0501531
# - 하수관로비율(MAX):  [-0.27605963]
# # 10000  손실 비용:  1.0493894
# - 하수관로비율(MAX):  [-0.2746104]
# # 10500  손실 비용:  1.0486376
# - 하수관로비율(MAX):  [-0.2731713]
# # 11000  손실 비용:  1.0478964
# - 하수관로비율(MAX):  [-0.27174062]
# # 11500  손실 비용:  1.0471667
# - 하수관로비율(MAX):  [-0.27032128]
# # 12000  손실 비용:  1.0464474
# - 하수관로비율(MAX):  [-0.26890966]
# # 12500  손실 비용:  1.0457386
# - 하수관로비율(MAX):  [-0.26750895]
# # 13000  손실 비용:  1.045041
# - 하수관로비율(MAX):  [-0.26611748]
# # 13500  손실 비용:  1.044352
# - 하수관로비율(MAX):  [-0.26473376]
# # 14000  손실 비용:  1.0436754
# - 하수관로비율(MAX):  [-0.26336223]
# # 14500  손실 비용:  1.0430074
# - 하수관로비율(MAX):  [-0.26199734]
# # 15000  손실 비용:  1.0423495
# - 하수관로비율(MAX):  [-0.26064333]
# # 15500  손실 비용:  1.0417
# - 하수관로비율(MAX):  [-0.2592957]
# # 16000  손실 비용:  1.0410621
# - 하수관로비율(MAX):  [-0.25796068]
# # 16500  손실 비용:  1.0404321
# - 하수관로비율(MAX):  [-0.2566319]
# # 17000  손실 비용:  1.0398118
# - 하수관로비율(MAX):  [-0.25531378]
# # 17500  손실 비용:  1.0392002
# - 하수관로비율(MAX):  [-0.25400308]
# # 18000  손실 비용:  1.0385975
# - 하수관로비율(MAX):  [-0.2527016]
# # 18500  손실 비용:  1.0380033
# - 하수관로비율(MAX):  [-0.2514087]
# # 19000  손실 비용:  1.037418
# - 하수관로비율(MAX):  [-0.2501243]
# # 19500  손실 비용:  1.0368414
# - 하수관로비율(MAX):  [-0.24884933]
# # 20000  손실 비용:  1.0362726
# - 하수관로비율(MAX):  [-0.24758118]
# # 20500  손실 비용:  1.0357122
# - 하수관로비율(MAX):  [-0.24632326]
# # 21000  손실 비용:  1.0351595
# - 하수관로비율(MAX):  [-0.24507137]
# # 21500  손실 비용:  1.0346156
# - 하수관로비율(MAX):  [-0.2438309]
# # 22000  손실 비용:  1.0340786
# - 하수관로비율(MAX):  [-0.24259534]
# # 22500  손실 비용:  1.03355
# - 하수관로비율(MAX):  [-0.24137121]
# # 23000  손실 비용:  1.0330282
# - 하수관로비율(MAX):  [-0.24015184]
# # 23500  손실 비용:  1.0325149
# - 하수관로비율(MAX):  [-0.23894419]
# # 24000  손실 비용:  1.0320079
# - 하수관로비율(MAX):  [-0.23774126]
# # 24500  손실 비용:  1.0315087
# - 하수관로비율(MAX):  [-0.23654887]
# # 25000  손실 비용:  1.031016
# - 하수관로비율(MAX):  [-0.23536184]
# # 25500  손실 비용:  1.0305313
# - 하수관로비율(MAX):  [-0.23418552]
# # 26000  손실 비용:  1.0300523
# - 하수관로비율(MAX):  [-0.23301402]
# # 26500  손실 비용:  1.029581
# - 하수관로비율(MAX):  [-0.23185259]
# # 27000  손실 비용:  1.0291153
# - 하수관로비율(MAX):  [-0.23069689]
# # 27500  손실 비용:  1.0286573
# - 하수관로비율(MAX):  [-0.22955112]
# # 28000  손실 비용:  1.0282046
# - 하수관로비율(MAX):  [-0.22840968]
# # 28500  손실 비용:  1.0277596
# - 하수관로비율(MAX):  [-0.22727944]
# # 29000  손실 비용:  1.0273197
# - 하수관로비율(MAX):  [-0.22615317]
# # 29500  손실 비용:  1.0268863
# - 하수관로비율(MAX):  [-0.22503716]
# # 30000  손실 비용:  1.0264589
# - 하수관로비율(MAX):  [-0.22392571]
# # 30500  손실 비용:  1.026038
# - 하수관로비율(MAX):  [-0.22282498]
# # 31000  손실 비용:  1.0256221
# - 하수관로비율(MAX):  [-0.22172752]
# # 31500  손실 비용:  1.0252129
# - 하수관로비율(MAX):  [-0.22064129]
# # 32000  손실 비용:  1.0248085
# - 하수관로비율(MAX):  [-0.21955884]
# # 32500  손실 비용:  1.0244104
# - 하수관로비율(MAX):  [-0.21848577]
# # 33000  손실 비용:  1.0240173
# - 하수관로비율(MAX):  [-0.21741825]
# # 33500  손실 비용:  1.0236299
# - 하수관로비율(MAX):  [-0.21635847]
# # 34000  손실 비용:  1.0232478
# - 하수관로비율(MAX):  [-0.21530531]
# # 34500  손실 비용:  1.0228709
# - 하수관로비율(MAX):  [-0.21425904]
# # 35000  손실 비용:  1.0224992
# - 하수관로비율(MAX):  [-0.21321963]
# # 35500  손실 비용:  1.0221326
# - 하수관로비율(MAX):  [-0.21218657]
# # 36000  손실 비용:  1.0217711
# - 하수관로비율(MAX):  [-0.21116123]
# # 36500  손실 비용:  1.0214142
# - 하수관로비율(MAX):  [-0.21014068]
# # 37000  손실 비용:  1.0210627
# - 하수관로비율(MAX):  [-0.20912963]
# # 37500  손실 비용:  1.0207155
# - 하수관로비율(MAX):  [-0.20812187]
# # 38000  손실 비용:  1.0203736
# - 하수관로비율(MAX):  [-0.2071241]
# # 38500  손실 비용:  1.0200354
# - 하수관로비율(MAX):  [-0.20612983]
# # 39000  손실 비용:  1.0197029
# - 하수관로비율(MAX):  [-0.2051442]
# # 39500  손실 비용:  1.0193741
# - 하수관로비율(MAX):  [-0.20416357]
# # 40000  손실 비용:  1.0190501
# - 하수관로비율(MAX):  [-0.20318955]
# # 40500  손실 비용:  1.0187305
# - 하수관로비율(MAX):  [-0.2022227]
# # 41000  손실 비용:  1.0184147
# - 하수관로비율(MAX):  [-0.20125975]
# # 41500  손실 비용:  1.0181038
# - 하수관로비율(MAX):  [-0.20030653]
# # 42000  손실 비용:  1.0177965
# - 하수관로비율(MAX):  [-0.19935663]
# # 42500  손실 비용:  1.0174941
# - 하수관로비율(MAX):  [-0.19841467]
# # 43000  손실 비용:  1.0171952
# - 하수관로비율(MAX):  [-0.19747797]
# # 43500  손실 비용:  1.0169
# - 하수관로비율(MAX):  [-0.19654667]
# # 44000  손실 비용:  1.0166094
# - 하수관로비율(MAX):  [-0.19562313]
# # 44500  손실 비용:  1.0163218
# - 하수관로비율(MAX):  [-0.1947025]
# # 45000  손실 비용:  1.0160383
# - 하수관로비율(MAX):  [-0.1937895]
# # 45500  손실 비용:  1.0157591
# - 하수관로비율(MAX):  [-0.19288242]
# # 46000  손실 비용:  1.0154831
# - 하수관로비율(MAX):  [-0.19198132]
# # 46500  손실 비용:  1.0152109
# - 하수관로비율(MAX):  [-0.1910863]
# # 47000  손실 비용:  1.0149426
# - 하수관로비율(MAX):  [-0.19019705]
# # 47500  손실 비용:  1.0146774
# - 하수관로비율(MAX):  [-0.18931308]
# # 48000  손실 비용:  1.0144157
# - 하수관로비율(MAX):  [-0.18843502]
# # 48500  손실 비용:  1.0141574
# - 하수관로비율(MAX):  [-0.18756185]
# # 49000  손실 비용:  1.013903
# - 하수관로비율(MAX):  [-0.18669575]
# # 49500  손실 비용:  1.0136513
# - 하수관로비율(MAX):  [-0.18583396]
# # 50000  손실 비용:  1.0134035
# - 하수관로비율(MAX):  [-0.18497878]
# # 50500  손실 비용:  1.0131582
# - 하수관로비율(MAX):  [-0.18412766]
# # 51000  손실 비용:  1.0129169
# - 하수관로비율(MAX):  [-0.18328309]
# # 51500  손실 비용:  1.012678
# - 하수관로비율(MAX):  [-0.18244365]
# # 52000  손실 비용:  1.0124425
# - 하수관로비율(MAX):  [-0.18160973]
# # 52500  손실 비용:  1.0122101
# - 하수관로비율(MAX):  [-0.18078086]
# # 53000  손실 비용:  1.0119803
# - 하수관로비율(MAX):  [-0.17995653]
# # 53500  손실 비용:  1.0117539
# - 하수관로비율(MAX):  [-0.17913905]
# # 54000  손실 비용:  1.0115303
# - 하수관로비율(MAX):  [-0.17832553]
# # 54500  손실 비용:  1.0113096
# - 하수관로비율(MAX):  [-0.17751814]
# # 55000  손실 비용:  1.0110917
# - 하수관로비율(MAX):  [-0.17671478]
# # 55500  손실 비용:  1.0108765
# - 하수관로비율(MAX):  [-0.17591733]
# # 56000  손실 비용:  1.0106643
# - 하수관로비율(MAX):  [-0.17512524]
# # 56500  손실 비용:  1.0104542
# - 하수관로비율(MAX):  [-0.17433676]
# # 57000  손실 비용:  1.0102475
# - 하수관로비율(MAX):  [-0.17355454]
# # 57500  손실 비용:  1.010043
# - 하수관로비율(MAX):  [-0.1727771]
# # 58000  손실 비용:  1.0098412
# - 하수관로비율(MAX):  [-0.17200454]
# # 58500  손실 비용:  1.009642
# - 하수관로비율(MAX):  [-0.17123689]
# # 59000  손실 비용:  1.009445
# - 하수관로비율(MAX):  [-0.170473]
# # 59500  손실 비용:  1.0092511
# - 하수관로비율(MAX):  [-0.16971597]
# # 60000  손실 비용:  1.0090593
# - 하수관로비율(MAX):  [-0.16896263]
# # 60500  손실 비용:  1.0088695
# - 하수관로비율(MAX):  [-0.16821322]
# # 61000  손실 비용:  1.0086828
# - 하수관로비율(MAX):  [-0.16747026]
# # 61500  손실 비용:  1.0084978
# - 하수관로비율(MAX):  [-0.16673101]
# # 62000  손실 비용:  1.0083156
# - 하수관로비율(MAX):  [-0.16599633]
# # 62500  손실 비용:  1.0081354
# - 하수관로비율(MAX):  [-0.16526671]
# # 63000  손실 비용:  1.0079572
# - 하수관로비율(MAX):  [-0.16454127]
# # 63500  손실 비용:  1.0077816
# - 하수관로비율(MAX):  [-0.16382091]
# # 64000  손실 비용:  1.0076078
# - 하수관로비율(MAX):  [-0.16310452]
# # 64500  손실 비용:  1.0074365
# - 하수관로비율(MAX):  [-0.16239269]
# # 65000  손실 비용:  1.0072676
# - 하수관로비율(MAX):  [-0.16168617]
# # 65500  손실 비용:  1.0071002
# - 하수관로비율(MAX):  [-0.16098297]
# # 66000  손실 비용:  1.0069348
# - 하수관로비율(MAX):  [-0.16028447]
# # 66500  손실 비용:  1.0067719
# - 하수관로비율(MAX):  [-0.15959132]
# # 67000  손실 비용:  1.0066108
# - 하수관로비율(MAX):  [-0.15890127]
# # 67500  손실 비용:  1.0064514
# - 하수관로비율(MAX):  [-0.15821578]
# # 68000  손실 비용:  1.0062945
# - 하수관로비율(MAX):  [-0.15753558]
# # 68500  손실 비용:  1.0061389
# - 하수관로비율(MAX):  [-0.15685838]
# # 69000  손실 비용:  1.0059855
# - 하수관로비율(MAX):  [-0.15618588]
# # 69500  손실 비용:  1.0058341
# - 하수관로비율(MAX):  [-0.15551813]
# # 70000  손실 비용:  1.0056845
# - 하수관로비율(MAX):  [-0.15485382]
# # 70500  손실 비용:  1.0055363
# - 하수관로비율(MAX):  [-0.15419392]
# # 71000  손실 비용:  1.0053902
# - 하수관로비율(MAX):  [-0.15353812]
# # 71500  손실 비용:  1.0052459
# - 하수관로비율(MAX):  [-0.15288664]
# # 72000  손실 비용:  1.0051035
# - 하수관로비율(MAX):  [-0.15223905]
# # 72500  손실 비용:  1.0049618
# - 하수관로비율(MAX):  [-0.15159473]
# # 73000  손실 비용:  1.004823
# - 하수관로비율(MAX):  [-0.15095599]
# # 73500  손실 비용:  1.0046854
# - 하수관로비율(MAX):  [-0.15032047]
# # 74000  손실 비용:  1.004549
# - 하수관로비율(MAX):  [-0.14968728]
# # 74500  손실 비용:  1.004415
# - 하수관로비율(MAX):  [-0.14906096]
# # 75000  손실 비용:  1.0042822
# - 하수관로비율(MAX):  [-0.14843728]
# # 75500  손실 비용:  1.0041507
# - 하수관로비율(MAX):  [-0.1478166]
# # 76000  손실 비용:  1.0040212
# - 하수관로비율(MAX):  [-0.14720073]
# # 76500  손실 비용:  1.0038934
# - 하수관로비율(MAX):  [-0.14658858]
# # 77000  손실 비용:  1.0037667
# - 하수관로비율(MAX):  [-0.14598045]
# # 77500  손실 비용:  1.0036414
# - 하수관로비율(MAX):  [-0.1453749]
# # 78000  손실 비용:  1.0035176
# - 하수관로비율(MAX):  [-0.14477415]
# # 78500  손실 비용:  1.0033958
# - 하수관로비율(MAX):  [-0.14417778]
# # 79000  손실 비용:  1.0032748
# - 하수관로비율(MAX):  [-0.14358336]
# # 79500  손실 비용:  1.003155
# - 하수관로비율(MAX):  [-0.14299306]
# # 80000  손실 비용:  1.0030372
# - 하수관로비율(MAX):  [-0.14240767]
# # 80500  손실 비용:  1.0029209
# - 하수관로비율(MAX):  [-0.14182515]
# # 81000  손실 비용:  1.0028056
# - 하수관로비율(MAX):  [-0.14124604]
# # 81500  손실 비용:  1.0026913
# - 하수관로비율(MAX):  [-0.14066918]
# # 82000  손실 비용:  1.002579
# - 하수관로비율(MAX):  [-0.14009893]
# # 82500  손실 비용:  1.0024674
# - 하수관로비율(MAX):  [-0.13953036]
# # 83000  손실 비용:  1.0023576
# - 하수관로비율(MAX):  [-0.13896532]
# # 83500  손실 비용:  1.0022483
# - 하수관로비율(MAX):  [-0.13840324]
# # 84000  손실 비용:  1.002141
# - 하수관로비율(MAX):  [-0.13784598]
# # 84500  손실 비용:  1.0020349
# - 하수관로비율(MAX):  [-0.13729206]
# # 85000  손실 비용:  1.0019295
# - 하수관로비율(MAX):  [-0.13673994]
# # 85500  손실 비용:  1.0018251
# - 하수관로비율(MAX):  [-0.1361919]
# # 86000  손실 비용:  1.0017226
# - 하수관로비율(MAX):  [-0.13564792]
# # 86500  손실 비용:  1.0016212
# - 하수관로비율(MAX):  [-0.1351079]
# # 87000  손실 비용:  1.0015208
# - 하수관로비율(MAX):  [-0.13456964]
# # 87500  손실 비용:  1.0014212
# - 하수관로비율(MAX):  [-0.13403468]
# # 88000  손실 비용:  1.0013229
# - 하수관로비율(MAX):  [-0.13350382]
# # 88500  손실 비용:  1.0012263
# - 하수관로비율(MAX):  [-0.13297656]
# # 89000  손실 비용:  1.0011301
# - 하수관로비율(MAX):  [-0.13245209]
# # 89500  손실 비용:  1.0010349
# - 하수관로비율(MAX):  [-0.13192979]
# # 90000  손실 비용:  1.0009408
# - 하수관로비율(MAX):  [-0.13141125]
# # 90500  손실 비용:  1.0008483
# - 하수관로비율(MAX):  [-0.13089657]
# # 91000  손실 비용:  1.0007565
# - 하수관로비율(MAX):  [-0.13038561]
# # 91500  손실 비용:  1.0006655
# - 하수관로비율(MAX):  [-0.12987584]
# # 92000  손실 비용:  1.0005757
# - 하수관로비율(MAX):  [-0.12937015]
# # 92500  손실 비용:  1.0004867
# - 하수관로비율(MAX):  [-0.12886658]
# # 93000  손실 비용:  1.0003992
# - 하수관로비율(MAX):  [-0.12836874]
# # 93500  손실 비용:  1.0003124
# - 하수관로비율(MAX):  [-0.12787163]
# # 94000  손실 비용:  1.0002265
# - 하수관로비율(MAX):  [-0.12737867]
# # 94500  손실 비용:  1.0001409
# - 하수관로비율(MAX):  [-0.12688655]
# # 95000  손실 비용:  1.0000572
# - 하수관로비율(MAX):  [-0.12640002]
# # 95500  손실 비용:  0.9999742
# - 하수관로비율(MAX):  [-0.1259155]
# # 96000  손실 비용:  0.9998921
# - 하수관로비율(MAX):  [-0.12543489]
# # 96500  손실 비용:  0.99981076
# - 하수관로비율(MAX):  [-0.12495517]
# # 97000  손실 비용:  0.9997299
# - 하수관로비율(MAX):  [-0.12447935]
# # 97500  손실 비용:  0.9996503
# - 하수관로비율(MAX):  [-0.12400559]
# # 98000  손실 비용:  0.9995718
# - 하수관로비율(MAX):  [-0.12353725]
# # 98500  손실 비용:  0.99949396
# - 하수관로비율(MAX):  [-0.12306951]
# # 99000  손실 비용:  0.9994168
# - 하수관로비율(MAX):  [-0.12260596]
# # 99500  손실 비용:  0.99934036
# - 하수관로비율(MAX):  [-0.1221429]
# # 100000  손실 비용:  0.9992648
# - 하수관로비율(MAX):  [-0.12168414]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# TensorFlow 그래프와 세션 설정
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()

# 학습 모델 불러오기
save_path = "./saved.cpkt"
saver = tf.compat.v1.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.compat.v1.get_default_graph()
X = graph.get_tensor_by_name("Placeholder:0")  # X 플레이스홀더 이름 변경
hypothesis = graph.get_tensor_by_name("add:0")  # hypothesis 텐서 이름 변경

# %%
# 사용자로부터 강수량을 입력받습니다.

onehr_rain_fall = float(input('1hr 최대 강수량(mm): '))
day_rain_fall = float(input('일평균 강수량(mm): '))
# Out:
# 1hr 최대 강수량(mm): 30
# 일평균 강수량(mm): 50

# %%
# 입력 데이터를 준비
data = np.array([[onehr_rain_fall, day_rain_fall]], dtype=np.float32)

feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict=feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 7.6862392
