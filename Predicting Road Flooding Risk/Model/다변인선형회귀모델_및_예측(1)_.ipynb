# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/Predicting%20Road%20Flooding%20Risk/Model/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(1)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 강수량과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlwo를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/강수량,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 1hr 최대 강수량(mm)      537
# 일평균 강수량(mm)         537
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 1hr 최대 강수량(mm)      0
# 일평균 강수량(mm)         0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  104.37206
# - 하수관로비율(MAX):  [0.72910243]
# # 500  손실 비용:  16.094337
# - 하수관로비율(MAX):  [0.7261102]
# # 1000  손실 비용:  13.598719
# - 하수관로비율(MAX):  [0.72725743]
# # 1500  손실 비용:  11.5649
# - 하수관로비율(MAX):  [0.7282646]
# # 2000  손실 비용:  9.853882
# - 하수관로비율(MAX):  [0.729024]
# # 2500  손실 비용:  8.414335
# - 하수관로비율(MAX):  [0.7295527]
# # 3000  손실 비용:  7.2031417
# - 하수관로비율(MAX):  [0.72987187]
# # 3500  손실 비용:  6.184044
# - 하수관로비율(MAX):  [0.72999835]
# # 4000  손실 비용:  5.326534
# - 하수관로비율(MAX):  [0.72994983]
# # 4500  손실 비용:  4.604949
# - 하수관로비율(MAX):  [0.72974074]
# # 5000  손실 비용:  3.997705
# - 하수관로비율(MAX):  [0.72938466]
# # 5500  손실 비용:  3.4866421
# - 하수관로비율(MAX):  [0.728896]
# # 6000  손실 비용:  3.0564919
# - 하수관로비율(MAX):  [0.72828484]
# # 6500  손실 비용:  2.6944027
# - 하수관로비율(MAX):  [0.72756195]
# # 7000  손실 비용:  2.389569
# - 하수관로비율(MAX):  [0.72673887]
# # 7500  손실 비용:  2.1328967
# - 하수관로비율(MAX):  [0.7258234]
# # 8000  손실 비용:  1.9167411
# - 하수관로비율(MAX):  [0.7248242]
# # 8500  손실 비용:  1.7346691
# - 하수관로비율(MAX):  [0.7237491]
# # 9000  손실 비용:  1.5812695
# - 하수관로비율(MAX):  [0.72260565]
# # 9500  손실 비용:  1.4519902
# - 하수관로비율(MAX):  [0.7213983]
# # 10000  손실 비용:  1.3430026
# - 하수관로비율(MAX):  [0.72013277]
# # 10500  손실 비용:  1.2510852
# - 하수관로비율(MAX):  [0.7188158]
# # 11000  손실 비용:  1.1735319
# - 하수관로비율(MAX):  [0.71745527]
# # 11500  손실 비용:  1.1080594
# - 하수관로비율(MAX):  [0.7160487]
# # 12000  손실 비용:  1.0527537
# - 하수관로비율(MAX):  [0.7146054]
# # 12500  손실 비용:  1.0060012
# - 하수관로비율(MAX):  [0.71312845]
# # 13000  손실 비용:  0.9664455
# - 하수관로비율(MAX):  [0.7116206]
# # 13500  손실 비용:  0.93294543
# - 하수관로비율(MAX):  [0.7100853]
# # 14000  손실 비용:  0.90454227
# - 하수관로비율(MAX):  [0.7085268]
# # 14500  손실 비용:  0.8804282
# - 하수관로비율(MAX):  [0.70694727]
# # 15000  손실 비용:  0.8599187
# - 하수관로비율(MAX):  [0.7053419]
# # 15500  손실 비용:  0.84245336
# - 하수관로비율(MAX):  [0.7037284]
# # 16000  손실 비용:  0.8275381
# - 하수관로비율(MAX):  [0.70208925]
# # 16500  손실 비용:  0.8147846
# - 하수관로비율(MAX):  [0.7004501]
# # 17000  손실 비용:  0.8038336
# - 하수관로비율(MAX):  [0.6987839]
# # 17500  손실 비용:  0.7944139
# - 하수관로비율(MAX):  [0.69711494]
# # 18000  손실 비용:  0.7862862
# - 하수관로비율(MAX):  [0.695446]
# # 18500  손실 비용:  0.77923506
# - 하수관로비율(MAX):  [0.69376]
# # 19000  손실 비용:  0.7730926
# - 하수관로비율(MAX):  [0.69206125]
# # 19500  손실 비용:  0.7677232
# - 하수관로비율(MAX):  [0.6903625]
# # 20000  손실 비용:  0.7630059
# - 하수관로비율(MAX):  [0.6886638]
# # 20500  손실 비용:  0.75883836
# - 하수관로비율(MAX):  [0.68696505]
# # 21000  손실 비용:  0.7551349
# - 하수관로비율(MAX):  [0.6852663]
# # 21500  손실 비용:  0.75182307
# - 하수관로비율(MAX):  [0.6835676]
# # 22000  손실 비용:  0.7488422
# - 하수관로비율(MAX):  [0.68186885]
# # 22500  손실 비용:  0.7461407
# - 하수관로비율(MAX):  [0.6801701]
# # 23000  손실 비용:  0.74367553
# - 하수관로비율(MAX):  [0.6784714]
# # 23500  손실 비용:  0.74141043
# - 하수관로비율(MAX):  [0.67677265]
# # 24000  손실 비용:  0.7393146
# - 하수관로비율(MAX):  [0.6750739]
# # 24500  손실 비용:  0.73736244
# - 하수관로비율(MAX):  [0.6733752]
# # 25000  손실 비용:  0.7355323
# - 하수관로비율(MAX):  [0.67167646]
# # 25500  손실 비용:  0.73380536
# - 하수관로비율(MAX):  [0.6699777]
# # 26000  손실 비용:  0.7321667
# - 하수관로비율(MAX):  [0.668279]
# # 26500  손실 비용:  0.73060304
# - 하수관로비율(MAX):  [0.66658026]
# # 27000  손실 비용:  0.7291097
# - 하수관로비율(MAX):  [0.6648906]
# # 27500  손실 비용:  0.72768545
# - 하수관로비율(MAX):  [0.66322166]
# # 28000  손실 비용:  0.72630787
# - 하수관로비율(MAX):  [0.6615527]
# # 28500  손실 비용:  0.724971
# - 하수관로비율(MAX):  [0.6598838]
# # 29000  손실 비용:  0.72366905
# - 하수관로비율(MAX):  [0.65821487]
# # 29500  손실 비용:  0.7223974
# - 하수관로비율(MAX):  [0.65654594]
# # 30000  손실 비용:  0.72115207
# - 하수관로비율(MAX):  [0.654877]
# # 30500  손실 비용:  0.7199471
# - 하수관로비율(MAX):  [0.65323466]
# # 31000  손실 비용:  0.7187644
# - 하수관로비율(MAX):  [0.65159553]
# # 31500  손실 비용:  0.71759945
# - 하수관로비율(MAX):  [0.6499564]
# # 32000  손실 비용:  0.7164502
# - 하수관로비율(MAX):  [0.6483173]
# # 32500  손실 비용:  0.715315
# - 하수관로비율(MAX):  [0.64667815]
# # 33000  손실 비용:  0.7142009
# - 하수관로비율(MAX):  [0.6450525]
# # 33500  손실 비용:  0.7131088
# - 하수관로비율(MAX):  [0.64344317]
# # 34000  손실 비용:  0.7120269
# - 하수관로비율(MAX):  [0.64183384]
# # 34500  손실 비용:  0.7109542
# - 하수관로비율(MAX):  [0.6402245]
# # 35000  손실 비용:  0.70989
# - 하수관로비율(MAX):  [0.6386152]
# # 35500  손실 비용:  0.7088409
# - 하수관로비율(MAX):  [0.6370171]
# # 36000  손실 비용:  0.7078111
# - 하수관로비율(MAX):  [0.63543755]
# # 36500  손실 비용:  0.70678806
# - 하수관로비율(MAX):  [0.633858]
# # 37000  손실 비용:  0.70577145
# - 하수관로비율(MAX):  [0.6322785]
# # 37500  손실 비용:  0.704761
# - 하수관로비율(MAX):  [0.630699]
# # 38000  손실 비용:  0.70376486
# - 하수관로비율(MAX):  [0.62913316]
# # 38500  손실 비용:  0.7027843
# - 하수관로비율(MAX):  [0.62758344]
# # 39000  손실 비용:  0.70180905
# - 하수관로비율(MAX):  [0.6260337]
# # 39500  손실 비용:  0.7008389
# - 하수관로비율(MAX):  [0.624484]
# # 40000  손실 비용:  0.6998736
# - 하수관로비율(MAX):  [0.6229343]
# # 40500  손실 비용:  0.6989243
# - 하수관로비율(MAX):  [0.62140256]
# # 41000  손실 비용:  0.6979868
# - 하수관로비율(MAX):  [0.61988264]
# # 41500  손실 비용:  0.6970537
# - 하수관로비율(MAX):  [0.6183627]
# # 42000  손실 비용:  0.696125
# - 하수관로비율(MAX):  [0.6168428]
# # 42500  손실 비용:  0.6952007
# - 하수관로비율(MAX):  [0.6153229]
# # 43000  손실 비용:  0.6942941
# - 하수관로비율(MAX):  [0.61382544]
# # 43500  손실 비용:  0.693396
# - 하수관로비율(MAX):  [0.6123353]
# # 44000  손실 비용:  0.692502
# - 하수관로비율(MAX):  [0.6108452]
# # 44500  손실 비용:  0.6916119
# - 하수관로비율(MAX):  [0.6093551]
# # 45000  손실 비용:  0.6907259
# - 하수관로비율(MAX):  [0.607865]
# # 45500  손실 비용:  0.689859
# - 하수관로비율(MAX):  [0.6064008]
# # 46000  손실 비용:  0.6889982
# - 하수관로비율(MAX):  [0.6049405]
# # 46500  손실 비용:  0.6881411
# - 하수관로비율(MAX):  [0.60348016]
# # 47000  손실 비용:  0.68728775
# - 하수관로비율(MAX):  [0.60201985]
# # 47500  손실 비용:  0.6864382
# - 하수관로비율(MAX):  [0.60055953]
# # 48000  손실 비용:  0.6856081
# - 하수관로비율(MAX):  [0.599127]
# # 48500  손실 비용:  0.68478286
# - 하수관로비율(MAX):  [0.5976965]
# # 49000  손실 비용:  0.6839612
# - 하수관로비율(MAX):  [0.596266]
# # 49500  손실 비용:  0.68314314
# - 하수관로비율(MAX):  [0.59483546]
# # 50000  손실 비용:  0.6823284
# - 하수관로비율(MAX):  [0.59340495]
# # 50500  손실 비용:  0.6815328
# - 하수관로비율(MAX):  [0.5920019]
# # 51000  손실 비용:  0.6807419
# - 하수관로비율(MAX):  [0.5906012]
# # 51500  손실 비용:  0.67995435
# - 하수관로비율(MAX):  [0.5892005]
# # 52000  손실 비용:  0.67917013
# - 하수관로비율(MAX):  [0.5877998]
# # 52500  손실 비용:  0.67838925
# - 하수관로비율(MAX):  [0.5863991]
# # 53000  손실 비용:  0.67762524
# - 하수관로비율(MAX):  [0.5850229]
# # 53500  손실 비용:  0.67686737
# - 하수관로비율(MAX):  [0.583652]
# # 54000  손실 비용:  0.67611283
# - 하수관로비율(MAX):  [0.5822811]
# # 54500  손실 비용:  0.67536145
# - 하수관로비율(MAX):  [0.5809102]
# # 55000  손실 비용:  0.6746131
# - 하수관로비율(MAX):  [0.5795393]
# # 55500  손실 비용:  0.67387825
# - 하수관로비율(MAX):  [0.5781872]
# # 56000  손실 비용:  0.67315227
# - 하수관로비율(MAX):  [0.5768461]
# # 56500  손실 비용:  0.6724297
# - 하수관로비율(MAX):  [0.575505]
# # 57000  손실 비용:  0.67170984
# - 하수관로비율(MAX):  [0.5741639]
# # 57500  손실 비용:  0.6709932
# - 하수관로비율(MAX):  [0.5728228]
# # 58000  손실 비용:  0.67028487
# - 하수관로비율(MAX):  [0.5714916]
# # 58500  손실 비용:  0.6695899
# - 하수관로비율(MAX):  [0.5701803]
# # 59000  손실 비용:  0.6688979
# - 하수관로비율(MAX):  [0.568869]
# # 59500  손실 비용:  0.66820884
# - 하수관로비율(MAX):  [0.5675577]
# # 60000  손실 비용:  0.6675227
# - 하수관로비율(MAX):  [0.5662464]
# # 60500  손실 비용:  0.6668394
# - 하수관로비율(MAX):  [0.5649351]
# # 61000  손실 비용:  0.6661732
# - 하수관로비율(MAX):  [0.56365114]
# # 61500  손실 비용:  0.6655112
# - 하수관로비율(MAX):  [0.56236964]
# # 62000  손실 비용:  0.66485167
# - 하수관로비율(MAX):  [0.56108814]
# # 62500  손실 비용:  0.6641952
# - 하수관로비율(MAX):  [0.55980664]
# # 63000  손실 비용:  0.6635413
# - 하수관로비율(MAX):  [0.55852515]
# # 63500  손실 비용:  0.6628961
# - 하수관로비율(MAX):  [0.557255]
# # 64000  손실 비용:  0.6622629
# - 하수관로비율(MAX):  [0.55600333]
# # 64500  손실 비용:  0.6616322
# - 하수관로비율(MAX):  [0.55475163]
# # 65000  손실 비용:  0.6610043
# - 하수관로비율(MAX):  [0.55349994]
# # 65500  손실 비용:  0.66037893
# - 하수관로비율(MAX):  [0.55224824]
# # 66000  손실 비용:  0.65975636
# - 하수관로비율(MAX):  [0.55099654]
# # 66500  손실 비용:  0.6591467
# - 하수관로비율(MAX):  [0.5497662]
# # 67000  손실 비용:  0.65854394
# - 하수관로비율(MAX):  [0.5485443]
# # 67500  손실 비용:  0.6579437
# - 하수관로비율(MAX):  [0.5473224]
# # 68000  손실 비용:  0.65734595
# - 하수관로비율(MAX):  [0.5461005]
# # 68500  손실 비용:  0.65675086
# - 하수관로비율(MAX):  [0.5448786]
# # 69000  손실 비용:  0.65615815
# - 하수관로비율(MAX):  [0.5436567]
# # 69500  손실 비용:  0.65558124
# - 하수관로비율(MAX):  [0.5424621]
# # 70000  손실 비용:  0.6550078
# - 하수관로비율(MAX):  [0.54127]
# # 70500  손실 비용:  0.6544367
# - 하수관로비율(MAX):  [0.5400779]
# # 71000  손실 비용:  0.65386814
# - 하수관로비율(MAX):  [0.53888583]
# # 71500  손실 비용:  0.65330195
# - 하수관로비율(MAX):  [0.53769374]
# # 72000  손실 비용:  0.65273803
# - 하수관로비율(MAX):  [0.53650165]
# # 72500  손실 비용:  0.65219027
# - 하수관로비율(MAX):  [0.5353385]
# # 73000  손실 비용:  0.6516451
# - 하수관로비율(MAX):  [0.53417623]
# # 73500  손실 비용:  0.65110224
# - 하수관로비율(MAX):  [0.53301394]
# # 74000  손실 비용:  0.6505618
# - 하수관로비율(MAX):  [0.53185165]
# # 74500  손실 비용:  0.65002364
# - 하수관로비율(MAX):  [0.53068936]
# # 75000  손실 비용:  0.64948756
# - 하수관로비율(MAX):  [0.52952707]
# # 75500  손실 비용:  0.64896584
# - 하수관로비율(MAX):  [0.5283908]
# # 76000  손실 비용:  0.64844775
# - 하수관로비율(MAX):  [0.52725834]
# # 76500  손실 비용:  0.647932
# - 하수관로비율(MAX):  [0.52612585]
# # 77000  손실 비용:  0.6474184
# - 하수관로비율(MAX):  [0.52499336]
# # 77500  손실 비용:  0.64690715
# - 하수관로비율(MAX):  [0.5238609]
# # 78000  손실 비용:  0.6463979
# - 하수관로비율(MAX):  [0.5227284]
# # 78500  손실 비용:  0.6458989
# - 하수관로비율(MAX):  [0.5216143]
# # 79000  손실 비용:  0.6454073
# - 하수관로비율(MAX):  [0.5205116]
# # 79500  손실 비용:  0.64491755
# - 하수관로비율(MAX):  [0.51940894]
# # 80000  손실 비용:  0.64443
# - 하수관로비율(MAX):  [0.51830626]
# # 80500  손실 비용:  0.64394444
# - 하수관로비율(MAX):  [0.51720357]
# # 81000  손실 비용:  0.64346087
# - 하수관로비율(MAX):  [0.5161009]
# # 81500  손실 비용:  0.64298195
# - 하수관로비율(MAX):  [0.515004]
# # 82000  손실 비용:  0.64251554
# - 하수관로비율(MAX):  [0.5139311]
# # 82500  손실 비용:  0.6420509
# - 하수관로비율(MAX):  [0.5128582]
# # 83000  손실 비용:  0.6415884
# - 하수관로비율(MAX):  [0.5117853]
# # 83500  손실 비용:  0.6411277
# - 하수관로비율(MAX):  [0.51071244]
# # 84000  손실 비용:  0.640669
# - 하수관로비율(MAX):  [0.50963956]
# # 84500  손실 비용:  0.6402122
# - 하수관로비율(MAX):  [0.5085667]
# # 85000  손실 비용:  0.63976485
# - 하수관로비율(MAX):  [0.5075114]
# # 85500  손실 비용:  0.6393244
# - 하수관로비율(MAX):  [0.5064683]
# # 86000  손실 비용:  0.638886
# - 하수관로비율(MAX):  [0.5054252]
# # 86500  손실 비용:  0.63844925
# - 하수관로비율(MAX):  [0.50438213]
# # 87000  손실 비용:  0.63801444
# - 하수관로비율(MAX):  [0.50333905]
# # 87500  손실 비용:  0.6375814
# - 하수관로비율(MAX):  [0.502296]
# # 88000  손실 비용:  0.63715005
# - 하수관로비율(MAX):  [0.5012529]
# # 88500  손실 비용:  0.6367305
# - 하수관로비율(MAX):  [0.5002336]
# # 89000  손실 비용:  0.63631094
# - 하수관로비율(MAX):  [0.49920973]
# # 89500  손실 비용:  0.63589716
# - 하수관로비율(MAX):  [0.49819645]
# # 90000  손실 비용:  0.6354853
# - 하수관로비율(MAX):  [0.49718317]
# # 90500  손실 비용:  0.6350751
# - 하수관로비율(MAX):  [0.4961699]
# # 91000  손실 비용:  0.63467
# - 하수관로비율(MAX):  [0.49516502]
# # 91500  손실 비용:  0.63426936
# - 하수관로비율(MAX):  [0.49416664]
# # 92000  손실 비용:  0.6338702
# - 하수관로비율(MAX):  [0.49316826]
# # 92500  손실 비용:  0.6334729
# - 하수관로비율(MAX):  [0.49217013]
# # 93000  손실 비용:  0.6330832
# - 하수관로비율(MAX):  [0.49118665]
# # 93500  손실 비용:  0.63269484
# - 하수관로비율(MAX):  [0.49020317]
# # 94000  손실 비용:  0.6323085
# - 하수관로비율(MAX):  [0.4892197]
# # 94500  손실 비용:  0.6319259
# - 하수관로비율(MAX):  [0.4882424]
# # 95000  손실 비용:  0.63154846
# - 하수관로비율(MAX):  [0.4872738]
# # 95500  손실 비용:  0.6311724
# - 하수관로비율(MAX):  [0.48630524]
# # 96000  손실 비용:  0.63079816
# - 하수관로비율(MAX):  [0.48533666]
# # 96500  손실 비용:  0.63042974
# - 하수관로비율(MAX):  [0.48437935]
# # 97000  손실 비용:  0.63006425
# - 하수관로비율(MAX):  [0.48342568]
# # 97500  손실 비용:  0.62970024
# - 하수관로비율(MAX):  [0.482472]
# # 98000  손실 비용:  0.62933815
# - 하수관로비율(MAX):  [0.48151895]
# # 98500  손실 비용:  0.6289828
# - 하수관로비율(MAX):  [0.48058018]
# # 99000  손실 비용:  0.62862897
# - 하수관로비율(MAX):  [0.4796414]
# # 99500  손실 비용:  0.6282768
# - 하수관로비율(MAX):  [0.47870263]
# # 100000  손실 비용:  0.6279274
# - 하수관로비율(MAX):  [0.47776788]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
import tensorflow.compat.v1 as tf
import numpy as np

# 모델 불러오기
sess = tf.Session()
save_path = "./saved.cpkt"
saver = tf.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.get_default_graph()
X = graph.get_tensor_by_name("X:0")
hypothesis = graph.get_tensor_by_name("add:0")

# %%
# 사용자로부터 강수량을 입력받습니다.

onehr_rain_fall = float(input('1hr 최대 강수량(mm): '))
day_rain_fall = float(input('일평균 강수량(mm): '))
# Out:
# 1hr 최대 강수량(mm): 13
# 일평균 강수량(mm): 80

# %%
# 입력 데이터 준비
data = np.array([[onehr_rain_fall, day_rain_fall]], dtype=np.float32)

# 예측 수행
feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.62453663

# %% [markdown]
# # **예측 모델 평가**
# - 평균 절대 오차(MAE)가 작을수록 모델의 예측이 실제 데이터와 더 가깝다는 의미
# - 결정 계수(R-squared)가 1에 가까울수록 모델이 주어진 데이터를 잘 설명한다는 의미

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = sess.run(hypothesis, feed_dict={X: x_data})

mae = mean_absolute_error(y_data, y_pred)
r2 = r2_score(y_data, y_pred)

print("평균 절대 오차(MAE):", mae)
print("결정계수(R-squared):", r2)
# Out:
# 평균 절대 오차(MAE): 0.33621088
# 결정계수(R-squared): -0.021881844719134458

# %% [markdown]
# ## **MSE**

# %%
# 예측 수행
feed_dict = {X: x_data}
y_pred = sess.run(hypothesis, feed_dict)

# Mean Squared Error 계산
mse = np.mean(np.square(y_data - y_pred))

# R-squared 계산
total_variance = np.var(y_data)
explained_variance = np.var(y_pred)
r2 = 1 - (mse / total_variance)

print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 0.62792677
