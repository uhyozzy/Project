# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 강수량과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlwo를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/강수량,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 1hr 최대 강수량(mm)      537
# 일평균 강수량(mm)         537
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 1hr 최대 강수량(mm)      0
# 일평균 강수량(mm)         0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  217.51291
# - 하수관로비율(MAX):  [-0.6812381]
# # 500  손실 비용:  5.558114
# - 하수관로비율(MAX):  [-0.66829056]
# # 1000  손실 비용:  4.709336
# - 하수관로비율(MAX):  [-0.66250235]
# # 1500  손실 비용:  4.1570454
# - 하수관로비율(MAX):  [-0.6570886]
# # 2000  손실 비용:  3.691756
# - 하수관로비율(MAX):  [-0.65183234]
# # 2500  손실 비용:  3.2995117
# - 하수관로비율(MAX):  [-0.6467152]
# # 3000  손실 비용:  2.968718
# - 하수관로비율(MAX):  [-0.64172864]
# # 3500  손실 비용:  2.6896222
# - 하수관로비율(MAX):  [-0.6368612]
# # 4000  손실 비용:  2.4540217
# - 하수관로비율(MAX):  [-0.63210577]
# # 4500  손실 비용:  2.2550137
# - 하수관로비율(MAX):  [-0.6274523]
# # 5000  손실 비용:  2.0867963
# - 하수관로비율(MAX):  [-0.62289596]
# # 5500  손실 비용:  1.9444835
# - 하수관로비율(MAX):  [-0.6184278]
# # 6000  손실 비용:  1.8239713
# - 하수관로비율(MAX):  [-0.61404425]
# # 6500  손실 비용:  1.7217999
# - 하수관로비율(MAX):  [-0.60973674]
# # 7000  손실 비용:  1.6350659
# - 하수관로비율(MAX):  [-0.6055021]
# # 7500  손실 비용:  1.5613222
# - 하수관로비율(MAX):  [-0.601334]
# # 8000  손실 비용:  1.4985131
# - 하수관로비율(MAX):  [-0.59722894]
# # 8500  손실 비용:  1.4449102
# - 하수관로비율(MAX):  [-0.59318334]
# # 9000  손실 비용:  1.3990558
# - 하수관로비율(MAX):  [-0.5891929]
# # 9500  손실 비용:  1.3597248
# - 하수관로비율(MAX):  [-0.58525306]
# # 10000  손실 비용:  1.3258903
# - 하수관로비율(MAX):  [-0.5813633]
# # 10500  손실 비용:  1.296684
# - 하수관로비율(MAX):  [-0.57751894]
# # 11000  손실 비용:  1.2713779
# - 하수관로비율(MAX):  [-0.57371825]
# # 11500  손실 비용:  1.2493542
# - 하수관로비율(MAX):  [-0.56995547]
# # 12000  손실 비용:  1.2301074
# - 하수관로비율(MAX):  [-0.5662355]
# # 12500  손실 비용:  1.2131957
# - 하수관로비율(MAX):  [-0.56255096]
# # 13000  손실 비용:  1.1982548
# - 하수관로비율(MAX):  [-0.5589003]
# # 13500  손실 비용:  1.1849779
# - 하수관로비율(MAX):  [-0.55528224]
# # 14000  손실 비용:  1.1731071
# - 하수관로비율(MAX):  [-0.5516956]
# # 14500  손실 비용:  1.1624255
# - 하수관로비율(MAX):  [-0.548139]
# # 15000  손실 비용:  1.1527499
# - 하수관로비율(MAX):  [-0.544611]
# # 15500  손실 비용:  1.1439254
# - 하수관로비율(MAX):  [-0.5411101]
# # 16000  손실 비용:  1.1358227
# - 하수관로비율(MAX):  [-0.5376347]
# # 16500  손실 비용:  1.1283313
# - 하수관로비율(MAX):  [-0.5341831]
# # 17000  손실 비용:  1.1213619
# - 하수관로비율(MAX):  [-0.5307558]
# # 17500  손실 비용:  1.1148425
# - 하수관로비율(MAX):  [-0.5273561]
# # 18000  손실 비용:  1.1086998
# - 하수관로비율(MAX):  [-0.5239766]
# # 18500  손실 비용:  1.102877
# - 하수관로비율(MAX):  [-0.52061546]
# # 19000  손실 비용:  1.0973359
# - 하수관로비율(MAX):  [-0.5172776]
# # 19500  손실 비용:  1.0920378
# - 하수관로비율(MAX):  [-0.5139626]
# # 20000  손실 비용:  1.08694
# - 하수관로비율(MAX):  [-0.510662]
# # 20500  손실 비용:  1.0820256
# - 하수관로비율(MAX):  [-0.50738376]
# # 21000  손실 비용:  1.0772691
# - 하수관로비율(MAX):  [-0.5041253]
# # 21500  손실 비용:  1.0726389
# - 하수관로비율(MAX):  [-0.50087714]
# # 22000  손실 비용:  1.0681419
# - 하수관로비율(MAX):  [-0.49765638]
# # 22500  손실 비용:  1.0637451
# - 하수관로비율(MAX):  [-0.4944485]
# # 23000  손실 비용:  1.0594426
# - 하수관로비율(MAX):  [-0.49125737]
# # 23500  손실 비용:  1.0552251
# - 하수관로비율(MAX):  [-0.48808324]
# # 24000  손실 비용:  1.0510845
# - 하수관로비율(MAX):  [-0.48492584]
# # 24500  손실 비용:  1.0470127
# - 하수관로비율(MAX):  [-0.48178414]
# # 25000  손실 비용:  1.0430036
# - 하수관로비율(MAX):  [-0.47865793]
# # 25500  손실 비용:  1.0390522
# - 하수관로비율(MAX):  [-0.47554696]
# # 26000  손실 비용:  1.0351542
# - 하수관로비율(MAX):  [-0.472451]
# # 26500  손실 비용:  1.031306
# - 하수관로비율(MAX):  [-0.46936986]
# # 27000  손실 비용:  1.0275044
# - 하수관로비율(MAX):  [-0.46630326]
# # 27500  손실 비용:  1.0237467
# - 하수관로비율(MAX):  [-0.46325102]
# # 28000  손실 비용:  1.0200305
# - 하수관로비율(MAX):  [-0.46021292]
# # 28500  손실 비용:  1.0163541
# - 하수관로비율(MAX):  [-0.45718876]
# # 29000  손실 비용:  1.0127159
# - 하수관로비율(MAX):  [-0.45417872]
# # 29500  손실 비용:  1.0091151
# - 하수관로비율(MAX):  [-0.4511832]
# # 30000  손실 비용:  1.0055496
# - 하수관로비율(MAX):  [-0.4482012]
# # 30500  손실 비용:  1.0020181
# - 하수관로비율(MAX):  [-0.44523257]
# # 31000  손실 비용:  0.99851954
# - 하수관로비율(MAX):  [-0.44227707]
# # 31500  손실 비용:  0.99505323
# - 하수관로비율(MAX):  [-0.43933457]
# # 32000  손실 비용:  0.9916181
# - 하수관로비율(MAX):  [-0.43640488]
# # 32500  손실 비용:  0.9882135
# - 하수관로비율(MAX):  [-0.43348783]
# # 33000  손실 비용:  0.98483896
# - 하수관로비율(MAX):  [-0.43058324]
# # 33500  손실 비용:  0.9814954
# - 하수관로비율(MAX):  [-0.4276924]
# # 34000  손실 비용:  0.9781819
# - 하수관로비율(MAX):  [-0.42481503]
# # 34500  손실 비용:  0.9748968
# - 하수관로비율(MAX):  [-0.4219498]
# # 35000  손실 비용:  0.9716397
# - 하수관로비율(MAX):  [-0.41909656]
# # 35500  손실 비용:  0.96841
# - 하수관로비율(MAX):  [-0.41625515]
# # 36000  손실 비용:  0.96520746
# - 하수관로비율(MAX):  [-0.41342545]
# # 36500  손실 비용:  0.96203357
# - 하수관로비율(MAX):  [-0.41060913]
# # 37000  손실 비용:  0.9588876
# - 하수관로비율(MAX):  [-0.40780586]
# # 37500  손실 비용:  0.95576775
# - 하수관로비율(MAX):  [-0.405014]
# # 38000  손실 비용:  0.95267355
# - 하수관로비율(MAX):  [-0.4022334]
# # 38500  손실 비용:  0.9496047
# - 하수관로비율(MAX):  [-0.39946392]
# # 39000  손실 비용:  0.9465628
# - 하수관로비율(MAX):  [-0.3967072]
# # 39500  손실 비용:  0.94354814
# - 하수관로비율(MAX):  [-0.3939636]
# # 40000  손실 비용:  0.94055784
# - 하수관로비율(MAX):  [-0.39123088]
# # 40500  손실 비용:  0.93759185
# - 하수관로비율(MAX):  [-0.38850886]
# # 41000  손실 비용:  0.9346496
# - 하수관로비율(MAX):  [-0.3857974]
# # 41500  손실 비용:  0.9317354
# - 하수관로비율(MAX):  [-0.3831003]
# # 42000  손실 비용:  0.928845
# - 하수관로비율(MAX):  [-0.38041422]
# # 42500  손실 비용:  0.92597777
# - 하수관로비율(MAX):  [-0.37773848]
# # 43000  손실 비용:  0.9231334
# - 하수관로비율(MAX):  [-0.37507293]
# # 43500  손실 비용:  0.920315
# - 하수관로비율(MAX):  [-0.37242052]
# # 44000  손실 비용:  0.91752076
# - 하수관로비율(MAX):  [-0.36977994]
# # 44500  손실 비용:  0.9147488
# - 하수관로비율(MAX):  [-0.3671493]
# # 45000  손실 비용:  0.9119986
# - 하수관로비율(MAX):  [-0.36452845]
# # 45500  손실 비용:  0.9092737
# - 하수관로비율(MAX):  [-0.36192074]
# # 46000  손실 비용:  0.9065719
# - 하수관로비율(MAX):  [-0.35932449]
# # 46500  손실 비용:  0.9038915
# - 하수관로비율(MAX):  [-0.3567378]
# # 47000  손실 비용:  0.90123206
# - 하수관로비율(MAX):  [-0.35416052]
# # 47500  손실 비용:  0.89859843
# - 하수관로비율(MAX):  [-0.35159752]
# # 48000  손실 비용:  0.8959857
# - 하수관로비율(MAX):  [-0.34904444]
# # 48500  손실 비용:  0.8933936
# - 하수관로비율(MAX):  [-0.34650055]
# # 49000  손실 비용:  0.89082307
# - 하수관로비율(MAX):  [-0.34396735]
# # 49500  손실 비용:  0.88827664
# - 하수관로비율(MAX):  [-0.34144738]
# # 50000  손실 비용:  0.8857499
# - 하수관로비율(MAX):  [-0.33893633]
# # 50500  손실 비용:  0.88324255
# - 하수관로비율(MAX):  [-0.33643404]
# # 51000  손실 비용:  0.8807594
# - 하수관로비율(MAX):  [-0.33394554]
# # 51500  손실 비용:  0.8782964
# - 하수관로비율(MAX):  [-0.3314668]
# # 52000  손실 비용:  0.87585217
# - 하수관로비율(MAX):  [-0.32899657]
# # 52500  손실 비용:  0.8734294
# - 하수관로비율(MAX):  [-0.32653788]
# # 53000  손실 비용:  0.87102836
# - 하수관로비율(MAX):  [-0.32409093]
# # 53500  손실 비용:  0.8686455
# - 하수관로비율(MAX):  [-0.32165223]
# # 54000  손실 비용:  0.8662822
# - 하수관로비율(MAX):  [-0.31922334]
# # 54500  손실 비용:  0.8639415
# - 하수관로비율(MAX):  [-0.31680763]
# # 55000  손실 비용:  0.86161834
# - 하수관로비율(MAX):  [-0.3143999]
# # 55500  손실 비용:  0.85931313
# - 하수관로비율(MAX):  [-0.3120008]
# # 56000  손실 비용:  0.85703117
# - 하수관로비율(MAX):  [-0.3096158]
# # 56500  손실 비용:  0.85476595
# - 하수관로비율(MAX):  [-0.30723846]
# # 57000  손실 비용:  0.8525181
# - 하수관로비율(MAX):  [-0.30486917]
# # 57500  손실 비용:  0.8502931
# - 하수관로비율(MAX):  [-0.3025143]
# # 58000  손실 비용:  0.8480846
# - 하수관로비율(MAX):  [-0.30016685]
# # 58500  손실 비용:  0.8458928
# - 하수관로비율(MAX):  [-0.29782736]
# # 59000  손실 비용:  0.8437232
# - 하수관로비율(MAX):  [-0.29550204]
# # 59500  손실 비용:  0.8415694
# - 하수관로비율(MAX):  [-0.29318383]
# # 60000  손실 비용:  0.8394326
# - 하수관로비율(MAX):  [-0.29087415]
# # 60500  손실 비용:  0.83731717
# - 하수관로비율(MAX):  [-0.28857782]
# # 61000  손실 비용:  0.8352167
# - 하수관로비율(MAX):  [-0.2862883]
# # 61500  손실 비용:  0.8331338
# - 하수관로비율(MAX):  [-0.2840084]
# # 62000  손실 비용:  0.83107066
# - 하수관로비율(MAX):  [-0.28174046]
# # 62500  손실 비용:  0.8290219
# - 하수관로비율(MAX):  [-0.279479]
# # 63000  손실 비용:  0.82699215
# - 하수관로비율(MAX):  [-0.27722892]
# # 63500  손실 비용:  0.8249796
# - 하수관로비율(MAX):  [-0.2749887]
# # 64000  손실 비용:  0.8229812
# - 하수관로비율(MAX):  [-0.2727547]
# # 64500  손실 비용:  0.82100344
# - 하수관로비율(MAX):  [-0.27053443]
# # 65000  손실 비용:  0.81904024
# - 하수관로비율(MAX):  [-0.26832134]
# # 65500  손실 비용:  0.8170922
# - 하수관로비율(MAX):  [-0.26611596]
# # 66000  손실 비용:  0.8151636
# - 하수관로비율(MAX):  [-0.26392367]
# # 66500  손실 비용:  0.8132484
# - 하수관로비율(MAX):  [-0.26173708]
# # 67000  손실 비용:  0.81135076
# - 하수관로비율(MAX):  [-0.2595615]
# # 67500  손실 비용:  0.80946904
# - 하수관로비율(MAX):  [-0.25739536]
# # 68000  손실 비용:  0.8076004
# - 하수관로비율(MAX):  [-0.2552347]
# # 68500  손실 비용:  0.80575204
# - 하수관로비율(MAX):  [-0.25308883]
# # 69000  손실 비용:  0.80391586
# - 하수관로비율(MAX):  [-0.2509482]
# # 69500  손실 비용:  0.80209655
# - 하수관로비율(MAX):  [-0.24881804]
# # 70000  손실 비용:  0.80029225
# - 하수관로비율(MAX):  [-0.24669658]
# # 70500  손실 비용:  0.7985027
# - 하수관로비율(MAX):  [-0.24458379]
# # 71000  손실 비용:  0.79672813
# - 하수관로비율(MAX):  [-0.24247964]
# # 71500  손실 비용:  0.7949681
# - 하수관로비율(MAX):  [-0.2403841]
# # 72000  손실 비용:  0.7932231
# - 하수관로비율(MAX):  [-0.23829752]
# # 72500  손실 비용:  0.79149306
# - 하수관로비율(MAX):  [-0.23622027]
# # 73000  손실 비용:  0.7897774
# - 하수관로비율(MAX):  [-0.23415156]
# # 73500  손실 비용:  0.788076
# - 하수관로비율(MAX):  [-0.23209134]
# # 74000  손실 비용:  0.7863887
# - 하수관로비율(MAX):  [-0.23003961]
# # 74500  손실 비용:  0.7847153
# - 하수관로비율(MAX):  [-0.22799633]
# # 75000  손실 비용:  0.7830561
# - 하수관로비율(MAX):  [-0.22596166]
# # 75500  손실 비용:  0.7814113
# - 하수관로비율(MAX):  [-0.22393619]
# # 76000  손실 비용:  0.7797801
# - 하수관로비율(MAX):  [-0.22191907]
# # 76500  손실 비용:  0.77816254
# - 하수관로비율(MAX):  [-0.21991031]
# # 77000  손실 비용:  0.7765583
# - 하수관로비율(MAX):  [-0.21790986]
# # 77500  손실 비용:  0.7749677
# - 하수관로비율(MAX):  [-0.21591769]
# # 78000  손실 비용:  0.77339005
# - 하수관로비율(MAX):  [-0.2139338]
# # 78500  손실 비용:  0.77182573
# - 하수관로비율(MAX):  [-0.21195816]
# # 79000  손실 비용:  0.7702744
# - 하수관로비율(MAX):  [-0.209991]
# # 79500  손실 비용:  0.76873666
# - 하수관로비율(MAX):  [-0.20803247]
# # 80000  손실 비용:  0.7672117
# - 하수관로비율(MAX):  [-0.20608209]
# # 80500  손실 비용:  0.76569945
# - 하수관로비율(MAX):  [-0.20413983]
# # 81000  손실 비용:  0.7641998
# - 하수관로비율(MAX):  [-0.20220566]
# # 81500  손실 비용:  0.76271266
# - 하수관로비율(MAX):  [-0.20027955]
# # 82000  손실 비용:  0.761238
# - 하수관로비율(MAX):  [-0.19836147]
# # 82500  손실 비용:  0.7597756
# - 하수관로비율(MAX):  [-0.19645141]
# # 83000  손실 비용:  0.75832546
# - 하수관로비율(MAX):  [-0.19454934]
# # 83500  손실 비용:  0.75688744
# - 하수관로비율(MAX):  [-0.1926552]
# # 84000  손실 비용:  0.75546134
# - 하수관로비율(MAX):  [-0.190769]
# # 84500  손실 비용:  0.75404716
# - 하수관로비율(MAX):  [-0.1888907]
# # 85000  손실 비용:  0.752645
# - 하수관로비율(MAX):  [-0.18702035]
# # 85500  손실 비용:  0.75125486
# - 하수관로비율(MAX):  [-0.18515813]
# # 86000  손실 비용:  0.74987614
# - 하수관로비율(MAX):  [-0.18330371]
# # 86500  손실 비용:  0.7485092
# - 하수관로비율(MAX):  [-0.18145704]
# # 87000  손실 비용:  0.7471535
# - 하수관로비율(MAX):  [-0.1796181]
# # 87500  손실 비용:  0.7458092
# - 하수관로비율(MAX):  [-0.17778687]
# # 88000  손실 비용:  0.74447626
# - 하수관로비율(MAX):  [-0.17596331]
# # 88500  손실 비용:  0.7431544
# - 하수관로비율(MAX):  [-0.1741474]
# # 89000  손실 비용:  0.74184346
# - 하수관로비율(MAX):  [-0.1723391]
# # 89500  손실 비용:  0.74054366
# - 하수관로비율(MAX):  [-0.17053837]
# # 90000  손실 비용:  0.7392548
# - 하수관로비율(MAX):  [-0.16874519]
# # 90500  손실 비용:  0.7379766
# - 하수관로비율(MAX):  [-0.16695954]
# # 91000  손실 비용:  0.7367091
# - 하수관로비율(MAX):  [-0.16518138]
# # 91500  손실 비용:  0.73545235
# - 하수관로비율(MAX):  [-0.16341068]
# # 92000  손실 비용:  0.7342059
# - 하수관로비율(MAX):  [-0.16164741]
# # 92500  손실 비용:  0.73297006
# - 하수관로비율(MAX):  [-0.15989153]
# # 93000  손실 비용:  0.7317445
# - 하수관로비율(MAX):  [-0.15814303]
# # 93500  손실 비용:  0.73052937
# - 하수관로비율(MAX):  [-0.15640186]
# # 94000  손실 비용:  0.7293243
# - 하수관로비율(MAX):  [-0.15466799]
# # 94500  손실 비용:  0.7281292
# - 하수관로비율(MAX):  [-0.15294138]
# # 95000  손실 비용:  0.7269442
# - 하수관로비율(MAX):  [-0.15122199]
# # 95500  손실 비용:  0.7257692
# - 하수관로비율(MAX):  [-0.14950982]
# # 96000  손실 비용:  0.7246039
# - 하수관로비율(MAX):  [-0.14780481]
# # 96500  손실 비용:  0.7234484
# - 하수관로비율(MAX):  [-0.14610694]
# # 97000  손실 비용:  0.7223026
# - 하수관로비율(MAX):  [-0.14441617]
# # 97500  손실 비용:  0.72116643
# - 하수관로비율(MAX):  [-0.14273246]
# # 98000  손실 비용:  0.7200397
# - 하수관로비율(MAX):  [-0.14105608]
# # 98500  손실 비용:  0.7189227
# - 하수관로비율(MAX):  [-0.13938683]
# # 99000  손실 비용:  0.7178151
# - 하수관로비율(MAX):  [-0.1377246]
# # 99500  손실 비용:  0.7167166
# - 하수관로비율(MAX):  [-0.13606931]
# # 100000  손실 비용:  0.71562743
# - 하수관로비율(MAX):  [-0.13442096]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
import tensorflow.compat.v1 as tf
import numpy as np

# 모델 불러오기
sess = tf.Session()
save_path = "./saved.cpkt"
saver = tf.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.get_default_graph()
X = graph.get_tensor_by_name("X:0")
hypothesis = graph.get_tensor_by_name("add:0")

# %%
# 사용자로부터 강수량을 입력받습니다.

onehr_rain_fall = float(input('1hr 최대 강수량(mm): '))
day_rain_fall = float(input('일평균 강수량(mm): '))
# Out:
# 1hr 최대 강수량(mm): 13
# 일평균 강수량(mm): 80

# %%
# 입력 데이터 준비
data = np.array([[onehr_rain_fall, day_rain_fall]], dtype=np.float32)

# 예측 수행
feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.31688392

# %% [markdown]
# # **예측 모델 평가**
# - 평균 절대 오차(MAE)가 작을수록 모델의 예측이 실제 데이터와 더 가깝다는 의미
# - 결정 계수(R-squared)가 1에 가까울수록 모델이 주어진 데이터를 잘 설명한다는 의미

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = sess.run(hypothesis, feed_dict={X: x_data})

mae = mean_absolute_error(y_data, y_pred)
r2 = r2_score(y_data, y_pred)

print("평균 절대 오차(MAE):", mae)
print("결정계수(R-squared):", r2)
# Out:
# 평균 절대 오차(MAE): 0.3762675
# 결정계수(R-squared): -0.16460145673937343
