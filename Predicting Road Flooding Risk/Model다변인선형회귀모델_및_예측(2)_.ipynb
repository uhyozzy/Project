# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/Predicting%20Road%20Flooding%20Risk/Model%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(2)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 지형과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlow를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/지형,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 경사도(˚)                0
# 해발고도(m)               0
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 경사도(˚)              0
# 해발고도(m)             0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  52972.04
# - 하수관로비율(MAX):  [-426.4118]
# # 500  손실 비용:  1.1873255
# - 하수관로비율(MAX):  [-0.42974162]
# # 1000  손실 비용:  1.1505188
# - 하수관로비율(MAX):  [-0.40764207]
# # 1500  손실 비용:  1.1162099
# - 하수관로비율(MAX):  [-0.38630724]
# # 2000  손실 비용:  1.0842279
# - 하수관로비율(MAX):  [-0.365709]
# # 2500  손실 비용:  1.0544156
# - 하수관로비율(MAX):  [-0.34582174]
# # 3000  손실 비용:  1.0266252
# - 하수관로비율(MAX):  [-0.32662237]
# # 3500  손실 비용:  1.0007197
# - 하수관로비율(MAX):  [-0.30808467]
# # 4000  손실 비용:  0.9765706
# - 하수관로비율(MAX):  [-0.2901879]
# # 4500  손실 비용:  0.9540592
# - 하수관로비율(MAX):  [-0.27290982]
# # 5000  손실 비용:  0.93307585
# - 하수관로비율(MAX):  [-0.25622845]
# # 5500  손실 비용:  0.9135141
# - 하수관로비율(MAX):  [-0.24012214]
# # 6000  손실 비용:  0.89527774
# - 하수관로비율(MAX):  [-0.2245729]
# # 6500  손실 비용:  0.8782794
# - 하수관로비율(MAX):  [-0.20956069]
# # 7000  손실 비용:  0.8624311
# - 하수관로비율(MAX):  [-0.19506669]
# # 7500  손실 비용:  0.84765893
# - 하수관로비율(MAX):  [-0.18107349]
# # 8000  손실 비용:  0.83388656
# - 하수관로비율(MAX):  [-0.16756362]
# # 8500  손실 비용:  0.8210468
# - 하수관로비율(MAX):  [-0.15451902]
# # 9000  손실 비용:  0.8090782
# - 하수관로비율(MAX):  [-0.14192724]
# # 9500  손실 비용:  0.7979197
# - 하수관로비율(MAX):  [-0.12976933]
# # 10000  손실 비용:  0.787516
# - 하수관로비율(MAX):  [-0.11803097]
# # 10500  손실 비용:  0.7778164
# - 하수관로비율(MAX):  [-0.10669738]
# # 11000  손실 비용:  0.76877487
# - 하수관로비율(MAX):  [-0.09575558]
# # 11500  손실 비용:  0.76034486
# - 하수관로비율(MAX):  [-0.0851922]
# # 12000  손실 비용:  0.75248516
# - 하수관로비율(MAX):  [-0.07499373]
# # 12500  손실 비용:  0.74515694
# - 하수관로비율(MAX):  [-0.06514716]
# # 13000  손실 비용:  0.7383242
# - 하수관로비율(MAX):  [-0.05564028]
# # 13500  손실 비용:  0.731953
# - 하수관로비율(MAX):  [-0.04646182]
# # 14000  손실 비용:  0.7260124
# - 하수관로비율(MAX):  [-0.03759968]
# # 14500  손실 비용:  0.72047293
# - 하수관로비율(MAX):  [-0.02904481]
# # 15000  손실 비용:  0.7153088
# - 하수관로비율(MAX):  [-0.02078557]
# # 15500  손실 비용:  0.71049327
# - 하수관로비율(MAX):  [-0.01281124]
# # 16000  손실 비용:  0.70600206
# - 하수관로비율(MAX):  [-0.00511175]
# # 16500  손실 비용:  0.70181304
# - 하수관로비율(MAX):  [0.00232303]
# # 17000  손실 비용:  0.6979063
# - 하수관로비율(MAX):  [0.00949997]
# # 17500  손실 비용:  0.6942648
# - 하수관로비율(MAX):  [0.01642787]
# # 18000  손실 비용:  0.6908674
# - 하수관로비율(MAX):  [0.02311814]
# # 18500  손실 비용:  0.6876969
# - 하수관로비율(MAX):  [0.02957904]
# # 19000  손실 비용:  0.6847429
# - 하수관로비율(MAX):  [0.03581262]
# # 19500  손실 비용:  0.68198574
# - 하수관로비율(MAX):  [0.04183412]
# # 20000  손실 비용:  0.67941326
# - 하수관로비율(MAX):  [0.04764712]
# # 20500  손실 비용:  0.67701524
# - 하수관로비율(MAX):  [0.0532583]
# # 21000  손실 비용:  0.6747749
# - 하수관로비율(MAX):  [0.05867946]
# # 21500  손실 비용:  0.67268854
# - 하수관로비율(MAX):  [0.06390792]
# # 22000  손실 비용:  0.6707384
# - 하수관로비율(MAX):  [0.06896192]
# # 22500  손실 비용:  0.66892177
# - 하수관로비율(MAX):  [0.07383519]
# # 23000  손실 비용:  0.6672233
# - 하수관로비율(MAX):  [0.07854682]
# # 23500  손실 비용:  0.6656415
# - 하수관로비율(MAX):  [0.08308887]
# # 24000  손실 비용:  0.6641614
# - 하수관로비율(MAX):  [0.08748055]
# # 24500  손실 비용:  0.66278356
# - 하수관로비율(MAX):  [0.0917151]
# # 25000  손실 비용:  0.6614946
# - 하수관로비율(MAX):  [0.09580731]
# # 25500  손실 비용:  0.66029245
# - 하수관로비율(MAX):  [0.09975719]
# # 26000  손실 비용:  0.65917003
# - 하수관로비율(MAX):  [0.10356939]
# # 26500  손실 비용:  0.6581194
# - 하수관로비율(MAX):  [0.10725582]
# # 27000  손실 비용:  0.6571419
# - 하수관로비율(MAX):  [0.11080635]
# # 27500  손실 비용:  0.65622663
# - 하수관로비율(MAX):  [0.11423898]
# # 28000  손실 비용:  0.6553707
# - 하수관로비율(MAX):  [0.1175561]
# # 28500  손실 비용:  0.6545736
# - 하수관로비율(MAX):  [0.12075162]
# # 29000  손실 비용:  0.6538266
# - 하수관로비율(MAX):  [0.12384129]
# # 29500  손실 비용:  0.65312725
# - 하수관로비율(MAX):  [0.12682825]
# # 30000  손실 비용:  0.6524767
# - 하수관로비율(MAX):  [0.1297031]
# # 30500  손실 비용:  0.65186673
# - 하수관로비율(MAX):  [0.13248283]
# # 31000  손실 비용:  0.6512946
# - 하수관로비율(MAX):  [0.1351707]
# # 31500  손실 비용:  0.65076125
# - 하수관로비율(MAX):  [0.13776189]
# # 32000  손실 비용:  0.65026283
# - 하수관로비율(MAX):  [0.14026111]
# # 32500  손실 비용:  0.6497947
# - 하수관로비율(MAX):  [0.14267784]
# # 33000  손실 비용:  0.64935523
# - 하수관로비율(MAX):  [0.14501446]
# # 33500  손실 비용:  0.6489459
# - 하수관로비율(MAX):  [0.14726597]
# # 34000  손실 비용:  0.64856285
# - 하수관로비율(MAX):  [0.14943683]
# # 34500  손실 비용:  0.64820284
# - 하수관로비율(MAX):  [0.15153658]
# # 35000  손실 비용:  0.64786404
# - 하수관로비율(MAX):  [0.15356666]
# # 35500  손실 비용:  0.6475457
# - 하수관로비율(MAX):  [0.15552938]
# # 36000  손실 비용:  0.64725065
# - 하수관로비율(MAX):  [0.1574136]
# # 36500  손실 비용:  0.64697254
# - 하수관로비율(MAX):  [0.15923524]
# # 37000  손실 비용:  0.64671075
# - 하수관로비율(MAX):  [0.16099697]
# # 37500  손실 비용:  0.6464637
# - 하수관로비율(MAX):  [0.16270071]
# # 38000  손실 비용:  0.64623064
# - 하수관로비율(MAX):  [0.16434819]
# # 38500  손실 비용:  0.6460136
# - 하수관로비율(MAX):  [0.16593349]
# # 39000  손실 비용:  0.64581037
# - 하수관로비율(MAX):  [0.1674599]
# # 39500  손실 비용:  0.64561826
# - 하수관로비율(MAX):  [0.1689362]
# # 40000  손실 비용:  0.6454365
# - 하수관로비율(MAX):  [0.17036366]
# # 40500  손실 비용:  0.6452646
# - 하수관로비율(MAX):  [0.17174375]
# # 41000  손실 비용:  0.64510167
# - 하수관로비율(MAX):  [0.17307818]
# # 41500  손실 비용:  0.64494723
# - 하수관로비율(MAX):  [0.17436928]
# # 42000  손실 비용:  0.64480466
# - 하수관로비율(MAX):  [0.17560577]
# # 42500  손실 비용:  0.64466983
# - 하수관로비율(MAX):  [0.17679942]
# # 43000  손실 비용:  0.6445416
# - 하수관로비율(MAX):  [0.17795396]
# # 43500  손실 비용:  0.6444197
# - 하수관로비율(MAX):  [0.1790694]
# # 44000  손실 비용:  0.64430356
# - 하수관로비율(MAX):  [0.18014842]
# # 44500  손실 비용:  0.6441931
# - 하수관로비율(MAX):  [0.18119287]
# # 45000  손실 비용:  0.6440876
# - 하수관로비율(MAX):  [0.18220216]
# # 45500  손실 비용:  0.64398694
# - 하수관로비율(MAX):  [0.18317771]
# # 46000  손실 비용:  0.64389133
# - 하수관로비율(MAX):  [0.18412042]
# # 46500  손실 비용:  0.6438032
# - 하수관로비율(MAX):  [0.18501985]
# # 47000  손실 비용:  0.6437189
# - 하수관로비율(MAX):  [0.18588853]
# # 47500  손실 비용:  0.64363796
# - 하수관로비율(MAX):  [0.18672979]
# # 48000  손실 비용:  0.64356035
# - 하수관로비율(MAX):  [0.18754268]
# # 48500  손실 비용:  0.64348584
# - 하수관로비율(MAX):  [0.18832874]
# # 49000  손실 비용:  0.6434142
# - 하수관로비율(MAX):  [0.18908894]
# # 49500  손실 비용:  0.6433451
# - 하수관로비율(MAX):  [0.18982434]
# # 50000  손실 비용:  0.6432785
# - 하수관로비율(MAX):  [0.1905359]
# # 50500  손실 비용:  0.64321405
# - 하수관로비율(MAX):  [0.19122273]
# # 51000  손실 비용:  0.64315194
# - 하수관로비율(MAX):  [0.19188827]
# # 51500  손실 비용:  0.6430918
# - 하수관로비율(MAX):  [0.1925323]
# # 52000  손실 비용:  0.64303344
# - 하수관로비율(MAX):  [0.19315386]
# # 52500  손실 비용:  0.6429795
# - 하수관로비율(MAX):  [0.1937468]
# # 53000  손실 비용:  0.6429282
# - 하수관로비율(MAX):  [0.19431609]
# # 53500  손실 비용:  0.64287823
# - 하수관로비율(MAX):  [0.1948654]
# # 54000  손실 비용:  0.6428296
# - 하수관로비율(MAX):  [0.1953969]
# # 54500  손실 비용:  0.6427823
# - 하수관로비율(MAX):  [0.19591129]
# # 55000  손실 비용:  0.6427361
# - 하수관로비율(MAX):  [0.19640875]
# # 55500  손실 비용:  0.642691
# - 하수관로비율(MAX):  [0.19688994]
# # 56000  손실 비용:  0.64264697
# - 하수관로비율(MAX):  [0.19735563]
# # 56500  손실 비용:  0.6426039
# - 하수관로비율(MAX):  [0.19780505]
# # 57000  손실 비용:  0.6425616
# - 하수관로비율(MAX):  [0.1982404]
# # 57500  손실 비용:  0.64252007
# - 하수관로비율(MAX):  [0.19866204]
# # 58000  손실 비용:  0.64247936
# - 하수관로비율(MAX):  [0.19906878]
# # 58500  손실 비용:  0.6424395
# - 하수관로비율(MAX):  [0.19946301]
# # 59000  손실 비용:  0.6424
# - 하수관로비율(MAX):  [0.19984412]
# # 59500  손실 비용:  0.6423614
# - 하수관로비율(MAX):  [0.20021343]
# # 60000  손실 비용:  0.642323
# - 하수관로비율(MAX):  [0.20056963]
# # 60500  손실 비용:  0.6422854
# - 하수관로비율(MAX):  [0.20091581]
# # 61000  손실 비용:  0.6422482
# - 하수관로비율(MAX):  [0.20124876]
# # 61500  손실 비용:  0.64221144
# - 하수관로비율(MAX):  [0.20157146]
# # 62000  손실 비용:  0.6421752
# - 하수관로비율(MAX):  [0.20188409]
# # 62500  손실 비용:  0.64213926
# - 하수관로비율(MAX):  [0.2021876]
# # 63000  손실 비용:  0.6421047
# - 하수관로비율(MAX):  [0.2024768]
# # 63500  손실 비용:  0.6420728
# - 하수관로비율(MAX):  [0.20274574]
# # 64000  손실 비용:  0.64204127
# - 하수관로비율(MAX):  [0.20300645]
# # 64500  손실 비용:  0.6420099
# - 하수관로비율(MAX):  [0.20325845]
# # 65000  손실 비용:  0.64197886
# - 하수관로비율(MAX):  [0.20350236]
# # 65500  손실 비용:  0.641948
# - 하수관로비율(MAX):  [0.20373857]
# # 66000  손실 비용:  0.6419173
# - 하수관로비율(MAX):  [0.20396739]
# # 66500  손실 비용:  0.6418869
# - 하수관로비율(MAX):  [0.20418704]
# # 67000  손실 비용:  0.6418566
# - 하수관로비율(MAX):  [0.20440048]
# # 67500  손실 비용:  0.64182657
# - 하수관로비율(MAX):  [0.20460713]
# # 68000  손실 비용:  0.6417966
# - 하수관로비율(MAX):  [0.20480764]
# # 68500  손실 비용:  0.6417667
# - 하수관로비율(MAX):  [0.20500255]
# # 69000  손실 비용:  0.64173716
# - 하수관로비율(MAX):  [0.20518893]
# # 69500  손실 비용:  0.6417076
# - 하수관로비율(MAX):  [0.20537037]
# # 70000  손실 비용:  0.6416781
# - 하수관로비율(MAX):  [0.2055468]
# # 70500  손실 비용:  0.6416488
# - 하수관로비율(MAX):  [0.20571631]
# # 71000  손실 비용:  0.6416197
# - 하수관로비율(MAX):  [0.20588034]
# # 71500  손실 비용:  0.6415905
# - 하수관로비율(MAX):  [0.20604116]
# # 72000  손실 비용:  0.64156145
# - 하수관로비율(MAX):  [0.20619386]
# # 72500  손실 비용:  0.64153254
# - 하수관로비율(MAX):  [0.20634359]
# # 73000  손실 비용:  0.64150363
# - 하수관로비율(MAX):  [0.20648783]
# # 73500  손실 비용:  0.6414749
# - 하수관로비율(MAX):  [0.20662755]
# # 74000  손실 비용:  0.64144605
# - 하수관로비율(MAX):  [0.20676345]
# # 74500  손실 비용:  0.6414175
# - 하수관로비율(MAX):  [0.20689398]
# # 75000  손실 비용:  0.64138865
# - 하수관로비율(MAX):  [0.20702147]
# # 75500  손실 비용:  0.6413601
# - 하수관로비율(MAX):  [0.2071439]
# # 76000  손실 비용:  0.6413315
# - 하수관로비율(MAX):  [0.20726305]
# # 76500  손실 비용:  0.641303
# - 하수관로비율(MAX):  [0.20737928]
# # 77000  손실 비용:  0.64127463
# - 하수관로비율(MAX):  [0.20749003]
# # 77500  손실 비용:  0.6412462
# - 하수관로비율(MAX):  [0.20760036]
# # 78000  손실 비용:  0.6412179
# - 하수관로비율(MAX):  [0.20770282]
# # 78500  손실 비용:  0.6411896
# - 하수관로비율(MAX):  [0.20780522]
# # 79000  손실 비용:  0.64116114
# - 하수관로비율(MAX):  [0.20790368]
# # 79500  손실 비용:  0.6411328
# - 하수관로비율(MAX):  [0.20799774]
# # 80000  손실 비용:  0.64110464
# - 하수관로비율(MAX):  [0.20809174]
# # 80500  손실 비용:  0.6410763
# - 하수관로비율(MAX):  [0.20818031]
# # 81000  손실 비용:  0.6410481
# - 하수관로비율(MAX):  [0.20826596]
# # 81500  손실 비용:  0.6410199
# - 하수관로비율(MAX):  [0.2083515]
# # 82000  손실 비용:  0.6409916
# - 하수관로비율(MAX):  [0.20843261]
# # 82500  손실 비용:  0.6409635
# - 하수관로비율(MAX):  [0.20850998]
# # 83000  손실 비용:  0.64093536
# - 하수관로비율(MAX):  [0.20858717]
# # 83500  손실 비용:  0.6409072
# - 하수관로비율(MAX):  [0.20866388]
# # 84000  손실 비용:  0.6408792
# - 하수관로비율(MAX):  [0.20873284]
# # 84500  손실 비용:  0.64085096
# - 하수관로비율(MAX):  [0.20880163]
# # 85000  손실 비용:  0.6408229
# - 하수관로비율(MAX):  [0.20887047]
# # 85500  손실 비용:  0.6407948
# - 하수관로비율(MAX):  [0.20893836]
# # 86000  손실 비용:  0.6407667
# - 하수관로비율(MAX):  [0.20899886]
# # 86500  손실 비용:  0.6407386
# - 하수관로비율(MAX):  [0.20905936]
# # 87000  손실 비용:  0.6407105
# - 하수관로비율(MAX):  [0.20911986]
# # 87500  손실 비용:  0.6406825
# - 하수관로비율(MAX):  [0.2091803]
# # 88000  손실 비용:  0.64065456
# - 하수관로비율(MAX):  [0.20923615]
# # 88500  손실 비용:  0.64062655
# - 하수관로비율(MAX):  [0.20928818]
# # 89000  손실 비용:  0.6405986
# - 하수관로비율(MAX):  [0.20934027]
# # 89500  손실 비용:  0.6405705
# - 하수관로비율(MAX):  [0.20939237]
# # 90000  손실 비용:  0.6405425
# - 하수관로비율(MAX):  [0.20944458]
# # 90500  손실 비용:  0.6405145
# - 하수관로비율(MAX):  [0.20949501]
# # 91000  손실 비용:  0.64048654
# - 하수관로비율(MAX):  [0.20953876]
# # 91500  손실 비용:  0.64045846
# - 하수관로비율(MAX):  [0.20958251]
# # 92000  손실 비용:  0.64043057
# - 하수관로비율(MAX):  [0.20962626]
# # 92500  손실 비용:  0.64040256
# - 하수관로비율(MAX):  [0.20967]
# # 93000  손실 비용:  0.64037466
# - 하수관로비율(MAX):  [0.2097137]
# # 93500  손실 비용:  0.6403468
# - 하수관로비율(MAX):  [0.20975745]
# # 94000  손실 비용:  0.6403188
# - 하수관로비율(MAX):  [0.20979637]
# # 94500  손실 비용:  0.64029086
# - 하수관로비율(MAX):  [0.20983166]
# # 95000  손실 비용:  0.640263
# - 하수관로비율(MAX):  [0.20986706]
# # 95500  손실 비용:  0.64023507
# - 하수관로비율(MAX):  [0.20990247]
# # 96000  손실 비용:  0.64020705
# - 하수관로비율(MAX):  [0.20993781]
# # 96500  손실 비용:  0.6401793
# - 하수관로비율(MAX):  [0.20997316]
# # 97000  손실 비용:  0.6401534
# - 하수관로비율(MAX):  [0.21000028]
# # 97500  손실 비용:  0.6401286
# - 하수관로비율(MAX):  [0.21002144]
# # 98000  손실 비용:  0.64010376
# - 하수관로비율(MAX):  [0.2100426]
# # 98500  손실 비용:  0.6400789
# - 하수관로비율(MAX):  [0.21006387]
# # 99000  손실 비용:  0.64005417
# - 하수관로비율(MAX):  [0.2100842]
# # 99500  손실 비용:  0.64002925
# - 하수관로비율(MAX):  [0.21009707]
# # 100000  손실 비용:  0.6400044
# - 하수관로비율(MAX):  [0.21010983]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# TensorFlow 그래프와 세션 설정
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()

# 학습 모델 불러오기
save_path = "./saved.cpkt"
saver = tf.compat.v1.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.compat.v1.get_default_graph()
X = graph.get_tensor_by_name("X:0")  # Placeholder 이름 변경
hypothesis = graph.get_tensor_by_name("add:0")  # hypothesis 텐서 이름 변경

# %%
# 사용자로부터 강수량을 입력받습니다.

gradient = float(input('경사도(˚): '))
altitude = float(input('해발고도(m): '))
# Out:
# 경사도(˚): 11
# 해발고도(m): 114

# %%
# 입력 데이터를 준비
data = np.array([[gradient, altitude]], dtype=np.float32)

feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict=feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.21572524

# %% [markdown]
# # **예측 모델 평가**
# - 평균 절대 오차(MAE)가 작을수록 모델의 예측이 실제 데이터와 더 가깝다는 의미
# - 결정 계수(R-squared)가 1에 가까울수록 모델이 주어진 데이터를 잘 설명한다는 의미

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = sess.run(hypothesis, feed_dict={X: x_data})

mae = mean_absolute_error(y_data, y_pred)
r2 = r2_score(y_data, y_pred)

print("평균 절대 오차(MAE):", mae)
print("결정계수(R-squared):", r2)
# Out:
# 평균 절대 오차(MAE): 0.28521717
# 결정계수(R-squared): -0.04153689542387928

# %% [markdown]
# ## **MSE**

# %%
# 예측 수행
feed_dict = {X: x_data}
y_pred = sess.run(hypothesis, feed_dict)

# Mean Squared Error 계산
mse = np.mean(np.square(y_data - y_pred))

# R-squared 계산
total_variance = np.var(y_data)
explained_variance = np.var(y_pred)
r2 = 1 - (mse / total_variance)

print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 0.6400044
