# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 지형과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlow를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/지형,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 경사도(˚)                0
# 해발고도(m)               0
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 경사도(˚)              0
# 해발고도(m)             0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  25.644287
# - 하수관로비율(MAX):  [10.450615]
# # 500  손실 비용:  4.4740024
# - 하수관로비율(MAX):  [1.9307207]
# # 1000  손실 비용:  4.2117853
# - 하수관로비율(MAX):  [1.8717248]
# # 1500  손실 비용:  3.9673731
# - 하수관로비율(MAX):  [1.8147627]
# # 2000  손실 비용:  3.7395544
# - 하수관로비율(MAX):  [1.7597718]
# # 2500  손실 비용:  3.5272064
# - 하수관로비율(MAX):  [1.7066787]
# # 3000  손실 비용:  3.329276
# - 하수관로비율(MAX):  [1.655421]
# # 3500  손실 비용:  3.1447873
# - 하수관로비율(MAX):  [1.6059346]
# # 4000  손실 비용:  2.9728243
# - 하수관로비율(MAX):  [1.5581572]
# # 4500  손실 비용:  2.812537
# - 하수관로비율(MAX):  [1.5120298]
# # 5000  손실 비용:  2.6631322
# - 하수관로비율(MAX):  [1.467497]
# # 5500  손실 비용:  2.5238729
# - 하수관로비율(MAX):  [1.4245019]
# # 6000  손실 비용:  2.3940685
# - 하수관로비율(MAX):  [1.3829919]
# # 6500  손실 비용:  2.2730784
# - 하수관로비율(MAX):  [1.3429163]
# # 7000  손실 비용:  2.1603029
# - 하수관로비율(MAX):  [1.3042253]
# # 7500  손실 비용:  2.055185
# - 하수관로비율(MAX):  [1.266869]
# # 8000  손실 비용:  1.957204
# - 하수관로비율(MAX):  [1.2308053]
# # 8500  손실 비용:  1.8658761
# - 하수관로비율(MAX):  [1.1959877]
# # 9000  손실 비용:  1.7807496
# - 하수관로비율(MAX):  [1.162372]
# # 9500  손실 비용:  1.7014024
# - 하수관로비율(MAX):  [1.1299167]
# # 10000  손실 비용:  1.6274434
# - 하수관로비율(MAX):  [1.098584]
# # 10500  손실 비용:  1.5585058
# - 하수관로비율(MAX):  [1.0683329]
# # 11000  손실 비용:  1.494249
# - 하수관로비율(MAX):  [1.039128]
# # 11500  손실 비용:  1.4343549
# - 하수관로비율(MAX):  [1.0109313]
# # 12000  손실 비용:  1.3785276
# - 하수관로비율(MAX):  [0.983708]
# # 12500  손실 비용:  1.3264909
# - 하수관로비율(MAX):  [0.9574258]
# # 13000  손실 비용:  1.277987
# - 하수관로비율(MAX):  [0.9320513]
# # 13500  손실 비용:  1.2327768
# - 하수관로비율(MAX):  [0.9075539]
# # 14000  손실 비용:  1.1906359
# - 하수관로비율(MAX):  [0.8839023]
# # 14500  손실 비용:  1.1513565
# - 하수관로비율(MAX):  [0.8610677]
# # 15000  손실 비용:  1.1147438
# - 하수관로비율(MAX):  [0.83902174]
# # 15500  손실 비용:  1.080617
# - 하수관로비율(MAX):  [0.8177382]
# # 16000  손실 비용:  1.0488071
# - 하수관로비율(MAX):  [0.79718924]
# # 16500  손실 비용:  1.0191573
# - 하수관로비율(MAX):  [0.77734977]
# # 17000  손실 비용:  0.9915204
# - 하수관로비율(MAX):  [0.7581965]
# # 17500  손실 비용:  0.96576005
# - 하수관로비율(MAX):  [0.7397042]
# # 18000  손실 비용:  0.94174856
# - 하수관로비율(MAX):  [0.7218508]
# # 18500  손실 비용:  0.91936755
# - 하수관로비율(MAX):  [0.7046146]
# # 19000  손실 비용:  0.8985058
# - 하수관로비율(MAX):  [0.6879735]
# # 19500  손실 비용:  0.8790605
# - 하수관로비율(MAX):  [0.6719075]
# # 20000  손실 비용:  0.86093557
# - 하수관로비율(MAX):  [0.6563961]
# # 20500  손실 비용:  0.84404117
# - 하수관로비율(MAX):  [0.6414208]
# # 21000  손실 비용:  0.82829356
# - 하수관로비율(MAX):  [0.62696296]
# # 21500  손실 비용:  0.81361514
# - 하수관로비율(MAX):  [0.6130043]
# # 22000  손실 비용:  0.7999332
# - 하수관로비율(MAX):  [0.5995279]
# # 22500  손실 비용:  0.7871802
# - 하수관로비율(MAX):  [0.586517]
# # 23000  손실 비용:  0.775293
# - 하수관로비율(MAX):  [0.57395566]
# # 23500  손실 비용:  0.7642127
# - 하수관로비율(MAX):  [0.5618281]
# # 24000  손실 비용:  0.7538847
# - 하수관로비율(MAX):  [0.55011964]
# # 24500  손실 비용:  0.74425775
# - 하수관로비율(MAX):  [0.5388155]
# # 25000  손실 비용:  0.73528427
# - 하수관로비율(MAX):  [0.52790195]
# # 25500  손실 비용:  0.72692
# - 하수관로비율(MAX):  [0.51736516]
# # 26000  손실 비용:  0.71912366
# - 하수관로비율(MAX):  [0.5071924]
# # 26500  손실 비용:  0.71185625
# - 하수관로비율(MAX):  [0.49737126]
# # 27000  손실 비용:  0.70508236
# - 하수관로비율(MAX):  [0.48788914]
# # 27500  손실 비용:  0.69876826
# - 하수관로비율(MAX):  [0.47873467]
# # 28000  손실 비용:  0.6928828
# - 하수관로비율(MAX):  [0.46989632]
# # 28500  손실 비용:  0.68739665
# - 하수관로비율(MAX):  [0.46136338]
# # 29000  손실 비용:  0.6822829
# - 하수관로비율(MAX):  [0.4531252]
# # 29500  손실 비용:  0.6775162
# - 하수관로비율(MAX):  [0.4451716]
# # 30000  손실 비용:  0.67307323
# - 하수관로비율(MAX):  [0.43749258]
# # 30500  손실 비용:  0.6689316
# - 하수관로비율(MAX):  [0.43007886]
# # 31000  손실 비용:  0.6650711
# - 하수관로비율(MAX):  [0.4229213]
# # 31500  손실 비용:  0.66147244
# - 하수관로비율(MAX):  [0.41601098]
# # 32000  손실 비용:  0.65811807
# - 하수관로비율(MAX):  [0.40933925]
# # 32500  손실 비용:  0.65499145
# - 하수관로비율(MAX):  [0.40289804]
# # 33000  손실 비용:  0.65207696
# - 하수관로비율(MAX):  [0.39667928]
# # 33500  손실 비용:  0.6493601
# - 하수관로비율(MAX):  [0.3906753]
# # 34000  손실 비용:  0.6468276
# - 하수관로비율(MAX):  [0.38487872]
# # 34500  손실 비용:  0.6444669
# - 하수관로비율(MAX):  [0.37928241]
# # 35000  손실 비용:  0.6422663
# - 하수관로비율(MAX):  [0.37387928]
# # 35500  손실 비용:  0.640215
# - 하수관로비율(MAX):  [0.3686629]
# # 36000  손실 비용:  0.63830286
# - 하수관로비율(MAX):  [0.36362666]
# # 36500  손실 비용:  0.6365204
# - 하수관로비율(MAX):  [0.35876435]
# # 37000  손실 비용:  0.6348588
# - 하수관로비율(MAX):  [0.35406995]
# # 37500  손실 비용:  0.6333099
# - 하수관로비율(MAX):  [0.34953767]
# # 38000  손실 비용:  0.63186604
# - 하수관로비율(MAX):  [0.34516197]
# # 38500  손실 비용:  0.6305201
# - 하수관로비율(MAX):  [0.34093738]
# # 39000  손실 비용:  0.62926537
# - 하수관로비율(MAX):  [0.33685875]
# # 39500  손실 비용:  0.6280957
# - 하수관로비율(MAX):  [0.33292097]
# # 40000  손실 비용:  0.62700516
# - 하수관로비율(MAX):  [0.32911912]
# # 40500  손실 비용:  0.6259887
# - 하수관로비율(MAX):  [0.32544857]
# # 41000  손실 비용:  0.625041
# - 하수관로비율(MAX):  [0.3219049]
# # 41500  손실 비용:  0.6241576
# - 하수관로비율(MAX):  [0.31848353]
# # 42000  손실 비용:  0.623334
# - 하수관로비율(MAX):  [0.3151803]
# # 42500  손실 비용:  0.6225661
# - 하수관로비율(MAX):  [0.31199116]
# # 43000  손실 비용:  0.6218504
# - 하수관로비율(MAX):  [0.30891216]
# # 43500  손실 비용:  0.6211829
# - 하수관로비율(MAX):  [0.30593947]
# # 44000  손실 비용:  0.62056065
# - 하수관로비율(MAX):  [0.30306953]
# # 44500  손실 비용:  0.61998063
# - 하수관로비율(MAX):  [0.3002987]
# # 45000  손실 비용:  0.6194398
# - 하수관로비율(MAX):  [0.29762343]
# # 45500  손실 비용:  0.61893535
# - 하수관로비율(MAX):  [0.29504058]
# # 46000  손실 비용:  0.61846524
# - 하수관로비율(MAX):  [0.29254696]
# # 46500  손실 비용:  0.6180268
# - 하수관로비율(MAX):  [0.29013944]
# # 47000  손실 비용:  0.61761796
# - 하수관로비율(MAX):  [0.28781518]
# # 47500  손실 비용:  0.61723685
# - 하수관로비율(MAX):  [0.28557104]
# # 48000  손실 비용:  0.6168814
# - 하수관로비율(MAX):  [0.28340444]
# # 48500  손실 비용:  0.6165499
# - 하수관로비율(MAX):  [0.2813125]
# # 49000  손실 비용:  0.61624086
# - 하수관로비율(MAX):  [0.2792929]
# # 49500  손실 비용:  0.61595273
# - 하수관로비율(MAX):  [0.2773429]
# # 50000  손실 비용:  0.6156838
# - 하수관로비율(MAX):  [0.2754602]
# # 50500  손실 비용:  0.61543304
# - 하수관로비율(MAX):  [0.27364308]
# # 51000  손실 비용:  0.61519915
# - 하수관로비율(MAX):  [0.2718881]
# # 51500  손실 비용:  0.6149811
# - 하수관로비율(MAX):  [0.27019376]
# # 52000  손실 비용:  0.6147777
# - 하수관로비율(MAX):  [0.26855814]
# # 52500  손실 비용:  0.61458796
# - 하수관로비율(MAX):  [0.2669788]
# # 53000  손실 비용:  0.61441094
# - 하수관로비율(MAX):  [0.26545405]
# # 53500  손실 비용:  0.6142457
# - 하수관로비율(MAX):  [0.26398224]
# # 54000  손실 비용:  0.6140917
# - 하수관로비율(MAX):  [0.2625606]
# # 54500  손실 비용:  0.6139478
# - 하수관로비율(MAX):  [0.26118842]
# # 55000  손실 비용:  0.6138138
# - 하수관로비율(MAX):  [0.2598638]
# # 55500  손실 비용:  0.6136885
# - 하수관로비율(MAX):  [0.25858444]
# # 56000  손실 비용:  0.6135717
# - 하수관로비율(MAX):  [0.25734967]
# # 56500  손실 비용:  0.6134626
# - 하수관로비율(MAX):  [0.25615704]
# # 57000  손실 비용:  0.6133609
# - 하수관로비율(MAX):  [0.25500596]
# # 57500  손실 비용:  0.6132658
# - 하수관로비율(MAX):  [0.25389436]
# # 58000  손실 비용:  0.6131772
# - 하수관로비율(MAX):  [0.25282145]
# # 58500  손실 비용:  0.6130945
# - 하수관로비율(MAX):  [0.25178522]
# # 59000  손실 비용:  0.6130171
# - 하수관로비율(MAX):  [0.250785]
# # 59500  손실 비용:  0.6129448
# - 하수관로비율(MAX):  [0.24981934]
# # 60000  손실 비용:  0.6128773
# - 하수관로비율(MAX):  [0.24888644]
# # 60500  손실 비용:  0.6128142
# - 하수관로비율(MAX):  [0.24798635]
# # 61000  손실 비용:  0.6127554
# - 하수관로비율(MAX):  [0.24711716]
# # 61500  손실 비용:  0.6127002
# - 하수관로비율(MAX):  [0.24627769]
# # 62000  손실 비용:  0.6126489
# - 하수관로비율(MAX):  [0.24546766]
# # 62500  손실 비용:  0.61260086
# - 하수관로비율(MAX):  [0.24468595]
# # 63000  손실 비용:  0.6125558
# - 하수관로비율(MAX):  [0.2439302]
# # 63500  손실 비용:  0.6125138
# - 하수관로비율(MAX):  [0.2432007]
# # 64000  손실 비용:  0.6124744
# - 하수관로비율(MAX):  [0.24249631]
# # 64500  손실 비용:  0.61243767
# - 하수관로비율(MAX):  [0.24181667]
# # 65000  손실 비용:  0.6124033
# - 하수관로비율(MAX):  [0.24116042]
# # 65500  손실 비용:  0.61237097
# - 하수관로비율(MAX):  [0.24052653]
# # 66000  손실 비용:  0.61234075
# - 하수관로비율(MAX):  [0.2399148]
# # 66500  손실 비용:  0.6123124
# - 하수관로비율(MAX):  [0.2393238]
# # 67000  손실 비용:  0.612286
# - 하수관로비율(MAX):  [0.23875387]
# # 67500  손실 비용:  0.612261
# - 하수관로비율(MAX):  [0.23820235]
# # 68000  손실 비용:  0.6122377
# - 하수관로비율(MAX):  [0.23767054]
# # 68500  손실 비용:  0.6122158
# - 하수관로비율(MAX):  [0.23715702]
# # 69000  손실 비용:  0.6121954
# - 하수관로비율(MAX):  [0.2366614]
# # 69500  손실 비용:  0.61217606
# - 하수관로비율(MAX):  [0.23618278]
# # 70000  손실 비용:  0.612158
# - 하수관로비율(MAX):  [0.2357212]
# # 70500  손실 비용:  0.61214095
# - 하수관로비율(MAX):  [0.23527539]
# # 71000  손실 비용:  0.6121249
# - 하수관로비율(MAX):  [0.23484436]
# # 71500  손실 비용:  0.61210984
# - 하수관로비율(MAX):  [0.23442693]
# # 72000  손실 비용:  0.6120958
# - 하수관로비율(MAX):  [0.23402692]
# # 72500  손실 비용:  0.6120824
# - 하수관로비율(MAX):  [0.2336383]
# # 73000  손실 비용:  0.6120697
# - 하수관로비율(MAX):  [0.23326375]
# # 73500  손실 비용:  0.6120579
# - 하수관로비율(MAX):  [0.23290181]
# # 74000  손실 비용:  0.6120468
# - 하수관로비율(MAX):  [0.2325534]
# # 74500  손실 비용:  0.6120362
# - 하수관로비율(MAX):  [0.2322166]
# # 75000  손실 비용:  0.61202615
# - 하수관로비율(MAX):  [0.23189023]
# # 75500  손실 비용:  0.6120168
# - 하수관로비율(MAX):  [0.23157671]
# # 76000  손실 비용:  0.61200774
# - 하수관로비율(MAX):  [0.23127314]
# # 76500  손실 비용:  0.61199933
# - 하수관로비율(MAX):  [0.23098025]
# # 77000  손실 비용:  0.6119912
# - 하수관로비율(MAX):  [0.23069696]
# # 77500  손실 비용:  0.61198366
# - 하수관로비율(MAX):  [0.2304246]
# # 78000  손실 비용:  0.6119764
# - 하수관로비율(MAX):  [0.23015945]
# # 78500  손실 비용:  0.6119694
# - 하수관로비율(MAX):  [0.22990401]
# # 79000  손실 비용:  0.61196285
# - 하수관로비율(MAX):  [0.22965786]
# # 79500  손실 비용:  0.61195666
# - 하수관로비율(MAX):  [0.22942176]
# # 80000  손실 비용:  0.6119506
# - 하수관로비율(MAX):  [0.22919336]
# # 80500  손실 비용:  0.61194485
# - 하수관로비율(MAX):  [0.22897175]
# # 81000  손실 비용:  0.6119395
# - 하수관로비율(MAX):  [0.22875813]
# # 81500  손실 비용:  0.6119342
# - 하수관로비율(MAX):  [0.22855034]
# # 82000  손실 비용:  0.61192924
# - 하수관로비율(MAX):  [0.22835034]
# # 82500  손실 비용:  0.6119245
# - 하수관로비율(MAX):  [0.22815868]
# # 83000  손실 비용:  0.61191994
# - 하수관로비율(MAX):  [0.22797418]
# # 83500  손실 비용:  0.61191547
# - 하수관로비율(MAX):  [0.22779384]
# # 84000  손실 비용:  0.611911
# - 하수관로비율(MAX):  [0.22761923]
# # 84500  손실 비용:  0.611907
# - 하수관로비율(MAX):  [0.22745284]
# # 85000  손실 비용:  0.6119029
# - 하수관로비율(MAX):  [0.2272906]
# # 85500  손실 비용:  0.6118991
# - 하수관로비율(MAX):  [0.22713336]
# # 86000  손실 비용:  0.61189544
# - 하수관로비율(MAX):  [0.22698471]
# # 86500  손실 비용:  0.6118918
# - 하수관로비율(MAX):  [0.22683862]
# # 87000  손실 비용:  0.61188835
# - 하수관로비율(MAX):  [0.22669902]
# # 87500  손실 비용:  0.6118849
# - 하수관로비율(MAX):  [0.22656205]
# # 88000  손실 비용:  0.61188155
# - 하수관로비율(MAX):  [0.22643092]
# # 88500  손실 비용:  0.61187834
# - 하수관로비율(MAX):  [0.2263039]
# # 89000  손실 비용:  0.6118751
# - 하수관로비율(MAX):  [0.22618112]
# # 89500  손실 비용:  0.6118722
# - 하수관로비율(MAX):  [0.22606307]
# # 90000  손실 비용:  0.6118692
# - 하수관로비율(MAX):  [0.22595051]
# # 90500  손실 비용:  0.6118665
# - 하수관로비율(MAX):  [0.22583848]
# # 91000  손실 비용:  0.61186343
# - 하수관로비율(MAX):  [0.22573426]
# # 91500  손실 비용:  0.6118607
# - 하수관로비율(MAX):  [0.2256301]
# # 92000  손실 비용:  0.61185795
# - 하수관로비율(MAX):  [0.22553232]
# # 92500  손실 비용:  0.61185527
# - 하수관로비율(MAX):  [0.22543645]
# # 93000  손실 비용:  0.6118525
# - 하수관로비율(MAX):  [0.22534075]
# # 93500  손실 비용:  0.6118499
# - 하수관로비율(MAX):  [0.22525334]
# # 94000  손실 비용:  0.6118473
# - 하수관로비율(MAX):  [0.22516581]
# # 94500  손실 비용:  0.61184484
# - 하수관로비율(MAX):  [0.22508043]
# # 95000  손실 비용:  0.6118424
# - 하수관로비율(MAX):  [0.22500312]
# # 95500  손실 비용:  0.61183995
# - 하수관로비율(MAX):  [0.22492582]
# # 96000  손실 비용:  0.6118376
# - 하수관로비율(MAX):  [0.22484726]
# # 96500  손실 비용:  0.6118351
# - 하수관로비율(MAX):  [0.22477835]
# # 97000  손실 비용:  0.61183286
# - 하수관로비율(MAX):  [0.22470945]
# # 97500  손실 비용:  0.6118306
# - 하수관로비율(MAX):  [0.22464043]
# # 98000  손실 비용:  0.6118283
# - 하수관로비율(MAX):  [0.22457296]
# # 98500  손실 비용:  0.61182594
# - 하수관로비율(MAX):  [0.22451234]
# # 99000  손실 비용:  0.61182374
# - 하수관로비율(MAX):  [0.22445184]
# # 99500  손실 비용:  0.6118214
# - 하수관로비율(MAX):  [0.22439122]
# # 100000  손실 비용:  0.6118191
# - 하수관로비율(MAX):  [0.22433114]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# TensorFlow 그래프와 세션 설정
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()

# 학습 모델 불러오기
save_path = "./saved.cpkt"
saver = tf.compat.v1.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.compat.v1.get_default_graph()
X = graph.get_tensor_by_name("X:0")  # Placeholder 이름 변경
hypothesis = graph.get_tensor_by_name("add:0")  # hypothesis 텐서 이름 변경

# %%
# 사용자로부터 강수량을 입력받습니다.

gradient = float(input('경사도(˚): '))
altitude = float(input('해발고도(m): '))
# Out:
# 경사도(˚): 11
# 해발고도(m): 114

# %%
# 입력 데이터를 준비
data = np.array([[gradient, altitude]], dtype=np.float32)

feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict=feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.30988953

# %% [markdown]
# # **예측 모델 평가**
# - 평균 절대 오차(MAE)가 작을수록 모델의 예측이 실제 데이터와 더 가깝다는 의미
# - 결정 계수(R-squared)가 1에 가까울수록 모델이 주어진 데이터를 잘 설명한다는 의미

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = sess.run(hypothesis, feed_dict={X: x_data})

mae = mean_absolute_error(y_data, y_pred)
r2 = r2_score(y_data, y_pred)

print("평균 절대 오차(MAE):", mae)
print("결정계수(R-squared):", r2)
# Out:
# 평균 절대 오차(MAE): 0.24382696
# 결정계수(R-squared): 0.0043313855880651175
