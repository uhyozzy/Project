# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 지형과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlow를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/지형,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 경사도(˚)                0
# 해발고도(m)               0
# [MAX] 하수관로 비율(%)    688
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 경사도(˚)              0
# 해발고도(m)             0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  8743.182
# - 하수관로비율(MAX):  [-172.57753]
# # 500  손실 비용:  0.76994747
# - 하수관로비율(MAX):  [0.46071196]
# # 1000  손실 비용:  0.76402235
# - 하수관로비율(MAX):  [0.4519031]
# # 1500  손실 비용:  0.7584923
# - 하수관로비율(MAX):  [0.443388]
# # 2000  손실 비용:  0.7533351
# - 하수관로비율(MAX):  [0.43517268]
# # 2500  손실 비용:  0.7485233
# - 하수관로비율(MAX):  [0.42724144]
# # 3000  손실 비용:  0.7440327
# - 하수관로비율(MAX):  [0.4195758]
# # 3500  손실 비용:  0.73984516
# - 하수관로비율(MAX):  [0.41218984]
# # 4000  손실 비용:  0.73593557
# - 하수관로비율(MAX):  [0.4050485]
# # 4500  손실 비용:  0.7322882
# - 하수관로비율(MAX):  [0.3981557]
# # 5000  손실 비용:  0.7288847
# - 하수관로비율(MAX):  [0.39150715]
# # 5500  손실 비용:  0.7257068
# - 하수관로비율(MAX):  [0.38508105]
# # 6000  손실 비용:  0.7227411
# - 하수관로비율(MAX):  [0.3788774]
# # 6500  손실 비용:  0.7199733
# - 하수관로비율(MAX):  [0.37289703]
# # 7000  손실 비용:  0.7173879
# - 하수관로비율(MAX):  [0.36711717]
# # 7500  손실 비용:  0.7149739
# - 하수관로비율(MAX):  [0.36152637]
# # 8000  손실 비용:  0.7127207
# - 하수관로비율(MAX):  [0.35615063]
# # 8500  손실 비용:  0.7106157
# - 하수관로비율(MAX):  [0.35095203]
# # 9000  손실 비용:  0.70864916
# - 하수관로비율(MAX):  [0.34592724]
# # 9500  손실 비용:  0.7068121
# - 하수관로비율(MAX):  [0.34107375]
# # 10000  손실 비용:  0.7050958
# - 하수관로비율(MAX):  [0.3364042]
# # 10500  손실 비용:  0.7034917
# - 하수관로비율(MAX):  [0.3318901]
# # 11000  손실 비용:  0.70199215
# - 하수관로비율(MAX):  [0.32752538]
# # 11500  손실 비용:  0.70059067
# - 하수관로비율(MAX):  [0.32330644]
# # 12000  손실 비용:  0.6992799
# - 하수관로비율(MAX):  [0.31924725]
# # 12500  손실 비용:  0.69805366
# - 하수관로비율(MAX):  [0.3153311]
# # 13000  손실 비용:  0.69690657
# - 하수관로비율(MAX):  [0.3115437]
# # 13500  손실 비용:  0.6958335
# - 하수관로비율(MAX):  [0.30788302]
# # 14000  손실 비용:  0.6948297
# - 하수관로비율(MAX):  [0.30434406]
# # 14500  손실 비용:  0.6938894
# - 하수관로비율(MAX):  [0.3009348]
# # 15000  손실 비용:  0.69300777
# - 하수관로비율(MAX):  [0.29765582]
# # 15500  손실 비용:  0.6921822
# - 하수관로비율(MAX):  [0.294482]
# # 16000  손실 비용:  0.69140893
# - 하수관로비율(MAX):  [0.291417]
# # 16500  손실 비용:  0.6906842
# - 하수관로비율(MAX):  [0.28845227]
# # 17000  손실 비용:  0.6900054
# - 하수관로비율(MAX):  [0.28558624]
# # 17500  손실 비용:  0.6893691
# - 하수관로비율(MAX):  [0.28281558]
# # 18000  손실 비용:  0.6887689
# - 하수관로비율(MAX):  [0.28016543]
# # 18500  손실 비용:  0.6882058
# - 하수관로비율(MAX):  [0.27760172]
# # 19000  손실 비용:  0.6876768
# - 하수관로비율(MAX):  [0.2751248]
# # 19500  손실 비용:  0.68718004
# - 하수관로비율(MAX):  [0.27273202]
# # 20000  손실 비용:  0.6867136
# - 하수관로비율(MAX):  [0.27041554]
# # 20500  손실 비용:  0.68627506
# - 하수관로비율(MAX):  [0.26817858]
# # 21000  손실 비용:  0.68586296
# - 하수관로비율(MAX):  [0.2660135]
# # 21500  손실 비용:  0.6854753
# - 하수관로비율(MAX):  [0.2639227]
# # 22000  손실 비용:  0.6851082
# - 하수관로비율(MAX):  [0.26191235]
# # 22500  손실 비용:  0.68475974
# - 하수관로비율(MAX):  [0.25998473]
# # 23000  손실 비용:  0.68443114
# - 하수관로비율(MAX):  [0.25812125]
# # 23500  손실 비용:  0.6841211
# - 하수관로비율(MAX):  [0.25632143]
# # 24000  손실 비용:  0.68382823
# - 하수관로비율(MAX):  [0.25457907]
# # 24500  손실 비용:  0.68355155
# - 하수관로비율(MAX):  [0.2528968]
# # 25000  손실 비용:  0.6832901
# - 하수관로비율(MAX):  [0.2512704]
# # 25500  손실 비용:  0.68304276
# - 하수관로비율(MAX):  [0.24969614]
# # 26000  손실 비용:  0.6828086
# - 하수관로비율(MAX):  [0.24817538]
# # 26500  손실 비용:  0.682587
# - 하수관로비율(MAX):  [0.24670565]
# # 27000  손실 비용:  0.68237686
# - 하수관로비율(MAX):  [0.24528682]
# # 27500  손실 비용:  0.6821778
# - 하수관로비율(MAX):  [0.24391246]
# # 28000  손실 비용:  0.68198735
# - 하수관로비율(MAX):  [0.24258757]
# # 28500  손실 비용:  0.68180126
# - 하수관로비율(MAX):  [0.24133289]
# # 29000  손실 비용:  0.68162394
# - 하수관로비율(MAX):  [0.24011803]
# # 29500  손실 비용:  0.68145454
# - 하수관로비율(MAX):  [0.23894632]
# # 30000  손실 비용:  0.68129283
# - 하수관로비율(MAX):  [0.23781174]
# # 30500  손실 비용:  0.6811383
# - 하수관로비율(MAX):  [0.23671377]
# # 31000  손실 비용:  0.6809903
# - 하수관로비율(MAX):  [0.23565501]
# # 31500  손실 비용:  0.6808485
# - 하수관로비율(MAX):  [0.2346313]
# # 32000  손실 비용:  0.6807126
# - 하수관로비율(MAX):  [0.23364073]
# # 32500  손실 비용:  0.6805823
# - 하수관로비율(MAX):  [0.23268378]
# # 33000  손실 비용:  0.68045694
# - 하수관로비율(MAX):  [0.23175836]
# # 33500  손실 비용:  0.68033653
# - 하수관로비율(MAX):  [0.23086673]
# # 34000  손실 비용:  0.6802204
# - 하수관로비율(MAX):  [0.23000228]
# # 34500  손실 비용:  0.6801088
# - 하수관로비율(MAX):  [0.22916615]
# # 35000  손실 비용:  0.6800009
# - 하수관로비율(MAX):  [0.22835875]
# # 35500  손실 비용:  0.67989695
# - 하수관로비율(MAX):  [0.22757989]
# # 36000  손실 비용:  0.6797962
# - 하수관로비율(MAX):  [0.22682387]
# # 36500  손실 비용:  0.67969894
# - 하수관로비율(MAX):  [0.22609746]
# # 37000  손실 비용:  0.67960465
# - 하수관로비율(MAX):  [0.22539157]
# # 37500  손실 비용:  0.6795132
# - 하수관로비율(MAX):  [0.22471112]
# # 38000  손실 비용:  0.67942446
# - 하수관로비율(MAX):  [0.22405422]
# # 38500  손실 비용:  0.6793381
# - 하수관로비율(MAX):  [0.2234177]
# # 39000  손실 비용:  0.6792544
# - 하수관로비율(MAX):  [0.22280258]
# # 39500  손실 비용:  0.6791722
# - 하수관로비율(MAX):  [0.22220922]
# # 40000  손실 비용:  0.6790847
# - 하수관로비율(MAX):  [0.2216633]
# # 40500  손실 비용:  0.6789991
# - 하수관로비율(MAX):  [0.22113597]
# # 41000  손실 비용:  0.6789153
# - 하수관로비율(MAX):  [0.22062624]
# # 41500  손실 비용:  0.67883307
# - 하수관로비율(MAX):  [0.22013354]
# # 42000  손실 비용:  0.6787523
# - 하수관로비율(MAX):  [0.21965677]
# # 42500  손실 비용:  0.67867315
# - 하수관로비율(MAX):  [0.21919686]
# # 43000  손실 비용:  0.6785951
# - 하수관로비율(MAX):  [0.21875215]
# # 43500  손실 비용:  0.6785185
# - 하수관로비율(MAX):  [0.21832216]
# # 44000  손실 비용:  0.67844296
# - 하수관로비율(MAX):  [0.21790624]
# # 44500  손실 비용:  0.6783685
# - 하수관로비율(MAX):  [0.21750546]
# # 45000  손실 비용:  0.6782952
# - 하수관로비율(MAX):  [0.21712023]
# # 45500  손실 비용:  0.6782229
# - 하수관로비율(MAX):  [0.21674633]
# # 46000  손실 비용:  0.67815155
# - 하수관로비율(MAX):  [0.21638376]
# # 46500  손실 비용:  0.6780809
# - 하수관로비율(MAX):  [0.2160325]
# # 47000  손실 비용:  0.6780113
# - 하수관로비율(MAX):  [0.21569866]
# # 47500  손실 비용:  0.67794245
# - 하수관로비율(MAX):  [0.21537125]
# # 48000  손실 비용:  0.67787427
# - 하수관로비율(MAX):  [0.2150538]
# # 48500  손실 비용:  0.67780685
# - 하수관로비율(MAX):  [0.21475327]
# # 49000  손실 비용:  0.67774004
# - 하수관로비율(MAX):  [0.21445775]
# # 49500  손실 비용:  0.6776738
# - 하수관로비율(MAX):  [0.21417528]
# # 50000  손실 비용:  0.6776084
# - 하수관로비율(MAX):  [0.21390152]
# # 50500  손실 비용:  0.6775433
# - 하수관로비율(MAX):  [0.21363574]
# # 51000  손실 비용:  0.6774788
# - 하수관로비율(MAX):  [0.21338183]
# # 51500  손실 비용:  0.6774146
# - 하수관로비율(MAX):  [0.21313292]
# # 52000  손실 비용:  0.6773511
# - 하수관로비율(MAX):  [0.21289682]
# # 52500  손실 비용:  0.67728794
# - 하수관로비율(MAX):  [0.21266472]
# # 53000  손실 비용:  0.6772252
# - 하수관로비율(MAX):  [0.21244425]
# # 53500  손실 비용:  0.6771629
# - 하수관로비율(MAX):  [0.2122289]
# # 54000  손실 비용:  0.677101
# - 하수관로비율(MAX):  [0.21202141]
# # 54500  손실 비용:  0.67703944
# - 하수관로비율(MAX):  [0.21182287]
# # 55000  손실 비용:  0.67697805
# - 하수관로비율(MAX):  [0.21162534]
# # 55500  손실 비용:  0.67691725
# - 하수관로비율(MAX):  [0.21144271]
# # 56000  손실 비용:  0.6768565
# - 하수관로비율(MAX):  [0.21126068]
# # 56500  손실 비용:  0.6767962
# - 하수관로비율(MAX):  [0.21108645]
# # 57000  손실 비용:  0.6767361
# - 하수관로비율(MAX):  [0.21092135]
# # 57500  손실 비용:  0.6766762
# - 하수관로비율(MAX):  [0.21075624]
# # 58000  손실 비용:  0.67661667
# - 하수관로비율(MAX):  [0.21060097]
# # 58500  손실 비용:  0.6765575
# - 하수관로비율(MAX):  [0.2104525]
# # 59000  손실 비용:  0.6764981
# - 하수관로비율(MAX):  [0.21030414]
# # 59500  손실 비용:  0.67643934
# - 하수관로비율(MAX):  [0.21016288]
# # 60000  손실 비용:  0.6763806
# - 하수관로비율(MAX):  [0.21003127]
# # 60500  손실 비용:  0.676322
# - 하수관로비율(MAX):  [0.20989949]
# # 61000  손실 비용:  0.6762635
# - 하수관로비율(MAX):  [0.20976627]
# # 61500  손실 비용:  0.6762055
# - 하수관로비율(MAX):  [0.20965075]
# # 62000  손실 비용:  0.6761474
# - 하수관로비율(MAX):  [0.20953584]
# # 62500  손실 비용:  0.6760896
# - 하수관로비율(MAX):  [0.20942092]
# # 63000  손실 비용:  0.67603165
# - 하수관로비율(MAX):  [0.20930499]
# # 63500  손실 비용:  0.67597425
# - 하수관로비율(MAX):  [0.20920497]
# # 64000  손실 비용:  0.67591673
# - 하수관로비율(MAX):  [0.2091068]
# # 64500  손실 비용:  0.67585963
# - 하수관로비율(MAX):  [0.2090087]
# # 65000  손실 비용:  0.67580223
# - 하수관로비율(MAX):  [0.20891058]
# # 65500  손실 비용:  0.6757452
# - 하수관로비율(MAX):  [0.20881492]
# # 66000  손실 비용:  0.6756883
# - 하수관로비율(MAX):  [0.20873344]
# # 66500  손실 비용:  0.6756315
# - 하수관로비율(MAX):  [0.20865214]
# # 67000  손실 비용:  0.67557484
# - 하수관로비율(MAX):  [0.20857072]
# # 67500  손실 비용:  0.67551816
# - 하수관로비율(MAX):  [0.20848942]
# # 68000  손실 비용:  0.67546153
# - 하수관로비율(MAX):  [0.20840812]
# # 68500  손실 비용:  0.675405
# - 하수관로비율(MAX):  [0.20833647]
# # 69000  손실 비용:  0.6753489
# - 하수관로비율(MAX):  [0.20827174]
# # 69500  손실 비용:  0.6752926
# - 하수관로비율(MAX):  [0.20820713]
# # 70000  손실 비용:  0.6752364
# - 하수관로비율(MAX):  [0.20814258]
# # 70500  손실 비용:  0.6751804
# - 하수관로비율(MAX):  [0.20807791]
# # 71000  손실 비용:  0.67512417
# - 하수관로비율(MAX):  [0.20801336]
# # 71500  손실 비용:  0.67506814
# - 하수관로비율(MAX):  [0.20794874]
# # 72000  손실 비용:  0.6750124
# - 하수관로비율(MAX):  [0.20789635]
# # 72500  손실 비용:  0.6749567
# - 하수관로비율(MAX):  [0.20784849]
# # 73000  손실 비용:  0.67490107
# - 하수관로비율(MAX):  [0.20780063]
# # 73500  손실 비용:  0.6748454
# - 하수관로비율(MAX):  [0.20775276]
# # 74000  손실 비용:  0.6747898
# - 하수관로비율(MAX):  [0.20770502]
# # 74500  손실 비용:  0.6747342
# - 하수관로비율(MAX):  [0.20765716]
# # 75000  손실 비용:  0.6746787
# - 하수관로비율(MAX):  [0.2076093]
# # 75500  손실 비용:  0.67462313
# - 하수관로비율(MAX):  [0.20756155]
# # 76000  손실 비용:  0.6745678
# - 하수관로비율(MAX):  [0.2075125]
# # 76500  손실 비용:  0.6745127
# - 하수관로비율(MAX):  [0.20747852]
# # 77000  손실 비용:  0.67445743
# - 하수관로비율(MAX):  [0.20744741]
# # 77500  손실 비용:  0.6744024
# - 하수관로비율(MAX):  [0.2074163]
# # 78000  손실 비용:  0.6743473
# - 하수관로비율(MAX):  [0.20738536]
# # 78500  손실 비용:  0.67429215
# - 하수관로비율(MAX):  [0.20735419]
# # 79000  손실 비용:  0.6742372
# - 하수관로비율(MAX):  [0.20732307]
# # 79500  손실 비용:  0.67418224
# - 하수관로비율(MAX):  [0.20729202]
# # 80000  손실 비용:  0.6741272
# - 하수관로비율(MAX):  [0.20726103]
# # 80500  손실 비용:  0.6740722
# - 하수관로비율(MAX):  [0.20722991]
# # 81000  손실 비용:  0.67401737
# - 하수관로비율(MAX):  [0.2071988]
# # 81500  손실 비용:  0.6739624
# - 하수관로비율(MAX):  [0.20716769]
# # 82000  손실 비용:  0.6739075
# - 하수관로비율(MAX):  [0.20713669]
# # 82500  손실 비용:  0.6738527
# - 하수관로비율(MAX):  [0.20710659]
# # 83000  손실 비용:  0.67379814
# - 하수관로비율(MAX):  [0.20709229]
# # 83500  손실 비용:  0.6737438
# - 하수관로비율(MAX):  [0.20707792]
# # 84000  손실 비용:  0.6736891
# - 하수관로비율(MAX):  [0.20706356]
# # 84500  손실 비용:  0.67363477
# - 하수관로비율(MAX):  [0.20704931]
# # 85000  손실 비용:  0.67358017
# - 하수관로비율(MAX):  [0.20703489]
# # 85500  손실 비용:  0.6735257
# - 하수관로비율(MAX):  [0.2070207]
# # 86000  손실 비용:  0.67347133
# - 하수관로비율(MAX):  [0.20700645]
# # 86500  손실 비용:  0.6734169
# - 하수관로비율(MAX):  [0.20699203]
# # 87000  손실 비용:  0.67336255
# - 하수관로비율(MAX):  [0.20697778]
# # 87500  손실 비용:  0.6733083
# - 하수관로비율(MAX):  [0.20696342]
# # 88000  손실 비용:  0.67325383
# - 하수관로비율(MAX):  [0.20694906]
# # 88500  손실 비용:  0.6731996
# - 하수관로비율(MAX):  [0.20693487]
# # 89000  손실 비용:  0.67314535
# - 하수관로비율(MAX):  [0.20692056]
# # 89500  손실 비용:  0.67309105
# - 하수관로비율(MAX):  [0.2069062]
# # 90000  손실 비용:  0.6730368
# - 하수관로비율(MAX):  [0.20689183]
# # 90500  손실 비용:  0.67298263
# - 하수관로비율(MAX):  [0.20687753]
# # 91000  손실 비용:  0.6729285
# - 하수관로비율(MAX):  [0.20686322]
# # 91500  손실 비용:  0.67287433
# - 하수관로비율(MAX):  [0.20684886]
# # 92000  손실 비용:  0.6728202
# - 하수관로비율(MAX):  [0.20683467]
# # 92500  손실 비용:  0.6727661
# - 하수관로비율(MAX):  [0.20682031]
# # 93000  손실 비용:  0.6727121
# - 하수관로비율(MAX):  [0.20680594]
# # 93500  손실 비용:  0.67265797
# - 하수관로비율(MAX):  [0.2067917]
# # 94000  손실 비용:  0.67260414
# - 하수관로비율(MAX):  [0.20678872]
# # 94500  손실 비용:  0.6725503
# - 하수관로비율(MAX):  [0.20679116]
# # 95000  손실 비용:  0.6724966
# - 하수관로비율(MAX):  [0.2067936]
# # 95500  손실 비용:  0.672443
# - 하수관로비율(MAX):  [0.20679605]
# # 96000  손실 비용:  0.6723891
# - 하수관로비율(MAX):  [0.20679843]
# # 96500  손실 비용:  0.67233545
# - 하수관로비율(MAX):  [0.20680094]
# # 97000  손실 비용:  0.6722819
# - 하수관로비율(MAX):  [0.20680338]
# # 97500  손실 비용:  0.6722281
# - 하수관로비율(MAX):  [0.20680577]
# # 98000  손실 비용:  0.6721746
# - 하수관로비율(MAX):  [0.20680821]
# # 98500  손실 비용:  0.6721211
# - 하수관로비율(MAX):  [0.20681071]
# # 99000  손실 비용:  0.6720674
# - 하수관로비율(MAX):  [0.2068131]
# # 99500  손실 비용:  0.6720139
# - 하수관로비율(MAX):  [0.2068156]
# # 100000  손실 비용:  0.67196035
# - 하수관로비율(MAX):  [0.20681804]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# TensorFlow 그래프와 세션 설정
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()

# 학습 모델 불러오기
save_path = "./saved.cpkt"
saver = tf.compat.v1.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.compat.v1.get_default_graph()
X = graph.get_tensor_by_name("X:0")  # Placeholder 이름 변경
hypothesis = graph.get_tensor_by_name("add:0")  # hypothesis 텐서 이름 변경

# %%
# 사용자로부터 강수량을 입력받습니다.

gradient = float(input('경사도(˚): '))
altitude = float(input('해발고도(m): '))
# Out:
# 경사도(˚): 9
# 해발고도(m): 68

# %%
# 입력 데이터를 준비
data = np.array([[gradient, altitude]], dtype=np.float32)

feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict=feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): 0.22497904
