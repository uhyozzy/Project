# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/Project/blob/master/%EB%8B%A4%EB%B3%80%EC%9D%B8%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80%EB%AA%A8%EB%8D%B8_%EB%B0%8F_%EC%98%88%EC%B8%A1(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **■ 강수량과 하수관로 비율 선형회귀 학습 후 예측**

# %% [markdown]
# # [1] TensorFlow를 이용한 **다변인 선형회귀 모델**

# %% [markdown]
# 참고1 : https://www.youtube.com/watch?v=9Ur7bbZtoTc 혹은 https://ndb796.tistory.com/126
#
# 참고2 : https://youtu.be/ve6gtpZV83E
#
# - 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델임. 현재 우리의 데이터에서는 변인이 '강수량', '지형', '지역환경이므로 이 모든 변인이 '하수관로비율'에 영향을 미친다고 감안해야 함.
# - 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
# 파일을 쉼표로 구분하여 읽어 데이터를 DataFrame 형태로 불러옴
data_origin = read_csv('/content/지형,하수관로.csv', sep=',')

# %%
# 결측치 확인
missing_values = data_origin.isnull().sum()
print(missing_values)
# Out:
# 경사도(˚)                0
# 해발고도(m)               0
# [MAX] 하수관로 비율(%)    151
# dtype: int64

# %%
# 결측치가 있는 행 제거한 후 확인
data = data_origin.dropna()
missing_values2 = data.isnull().sum()
print(missing_values2)
# Out:
# 경사도(˚)              0
# 해발고도(m)             0
# [MAX] 하수관로 비율(%)    0
# dtype: int64

# %%
# DataFrame을 NumPy 배열로 변환하고 데이터 타입을 float32로 지정
xy = np.array(data, dtype=np.float32)

# %%
# 2개의 변인을 입력을 받음
x_data = xy[:, 0:2]

# %%
# 하수관로(MAX) 값을 입력 받음
# 출력 데이터로 사용할 마지막 열의 데이터를 추출
y_data = xy[:, [-1]]

# %%
# 입력 데이터를 위한 TensorFlow placeholder를 생성합니다.
# 데이터 형태는 [None, 2]과 [None, 1]인데, None은 임의의 행 개수를 의미 -> X는 2개의 변인, y는 1개의 변인
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2], name="X")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="Y")

# %%
# 가중치 변수 W를 생성. 초기값은 정규 분포를 따르는 랜덤한 값임
W = tf.Variable(tf.random_normal([2, 1]), name="weight")

# %%
# 편향 변수 b를 생성
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다.(평균 제곱 오차를 계산 )
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정

# 경사 하강법 최적화기를 생성하고 학습률을 설정
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
# 비용 함수를 최소화하기 위한 훈련 오퍼레이션을 생성
train = optimizer.minimize(cost)

# %%
# 세션을 생성
sess = tf.Session()

# %%
# 글로벌 변수를 초기화
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **학습 수행**
# - ※주의※ Nan값 있으면 학습이 제대로 수행안되니 결측치 필수로 제거 후 학습 진행

# %%
# 학습을 수행합니다.

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 하수관로비율(MAX): ", hypo_[0])

# 100001번 반복하는 학습 루프
# 학습을 수행하면서 비용, 가설 값, 훈련을 실행하여 비용 최소화를 진행
# 매 500번째 스텝마다 학습 상황에 대한 내용을 출력
# Out:
# # 0  손실 비용:  4.4169626
# - 하수관로비율(MAX):  [2.638307]
# # 500  손실 비용:  4.3525767
# - 하수관로비율(MAX):  [2.6099687]
# # 1000  손실 비용:  4.2894444
# - 하수관로비율(MAX):  [2.5819173]
# # 1500  손실 비용:  4.227484
# - 하수관로비율(MAX):  [2.5541267]
# # 2000  손실 비용:  4.1667037
# - 하수관로비율(MAX):  [2.5266068]
# # 2500  손실 비용:  4.1070805
# - 하수관로비율(MAX):  [2.4993548]
# # 3000  손실 비용:  4.048563
# - 하수관로비율(MAX):  [2.4723558]
# # 3500  손실 비용:  3.9911852
# - 하수관로비율(MAX):  [2.4456317]
# # 4000  손실 비용:  3.9348779
# - 하수관로비율(MAX):  [2.4191582]
# # 4500  손실 비용:  3.8796215
# - 하수관로비율(MAX):  [2.3929331]
# # 5000  손실 비용:  3.825443
# - 하수관로비율(MAX):  [2.3669746]
# # 5500  손실 비용:  3.7722747
# - 하수관로비율(MAX):  [2.34126]
# # 6000  손실 비용:  3.7200997
# - 하수관로비율(MAX):  [2.3157876]
# # 6500  손실 비용:  3.668933
# - 하수관로비율(MAX):  [2.290571]
# # 7000  손실 비용:  3.618733
# - 하수관로비율(MAX):  [2.2655957]
# # 7500  손실 비용:  3.569472
# - 하수관로비율(MAX):  [2.240857]
# # 8000  손실 비용:  3.5211341
# - 하수관로비율(MAX):  [2.2163525]
# # 8500  손실 비용:  3.4737394
# - 하수관로비율(MAX):  [2.192098]
# # 9000  손실 비용:  3.4272335
# - 하수관로비율(MAX):  [2.1680727]
# # 9500  손실 비용:  3.3816009
# - 하수관로비율(MAX):  [2.1442761]
# # 10000  손실 비용:  3.3368258
# - 하수관로비율(MAX):  [2.1207066]
# # 10500  손실 비용:  3.292901
# - 하수관로비율(MAX):  [2.0973668]
# # 11000  손실 비용:  3.2498224
# - 하수관로비율(MAX):  [2.0742583]
# # 11500  손실 비용:  3.207554
# - 하수관로비율(MAX):  [2.0513709]
# # 12000  손실 비용:  3.1660821
# - 하수관로비율(MAX):  [2.0287023]
# # 12500  손실 비용:  3.1253908
# - 하수관로비율(MAX):  [2.0062518]
# # 13000  손실 비용:  3.0854673
# - 하수관로비율(MAX):  [1.9840158]
# # 13500  손실 비용:  3.0462978
# - 하수관로비율(MAX):  [1.9619935]
# # 14000  손실 비용:  3.0078785
# - 하수관로비율(MAX):  [1.940189]
# # 14500  손실 비용:  2.97019
# - 하수관로비율(MAX):  [1.9185978]
# # 15000  손실 비용:  2.9332135
# - 하수관로비율(MAX):  [1.8972131]
# # 15500  손실 비용:  2.8969347
# - 하수관로비율(MAX):  [1.8760345]
# # 16000  손실 비용:  2.8613415
# - 하수관로비율(MAX):  [1.8550606]
# # 16500  손실 비용:  2.8264208
# - 하수관로비율(MAX):  [1.8342885]
# # 17000  손실 비용:  2.792161
# - 하수관로비율(MAX):  [1.8137165]
# # 17500  손실 비용:  2.7585487
# - 하수관로비율(MAX):  [1.7933438]
# # 18000  손실 비용:  2.7255726
# - 하수관로비율(MAX):  [1.7731682]
# # 18500  손실 비용:  2.69322
# - 하수관로비율(MAX):  [1.7531866]
# # 19000  손실 비용:  2.6614797
# - 하수관로비율(MAX):  [1.7333987]
# # 19500  손실 비용:  2.6303406
# - 하수관로비율(MAX):  [1.7138027]
# # 20000  손실 비용:  2.5997906
# - 하수관로비율(MAX):  [1.6943955]
# # 20500  손실 비용:  2.5698185
# - 하수관로비율(MAX):  [1.6751764]
# # 21000  손실 비용:  2.540414
# - 하수관로비율(MAX):  [1.6561435]
# # 21500  손실 비용:  2.5115654
# - 하수관로비율(MAX):  [1.637294]
# # 22000  손실 비용:  2.4832623
# - 하수관로비율(MAX):  [1.6186267]
# # 22500  손실 비용:  2.4554942
# - 하수관로비율(MAX):  [1.6001402]
# # 23000  손실 비용:  2.4282506
# - 하수관로비율(MAX):  [1.5818318]
# # 23500  손실 비용:  2.4015212
# - 하수관로비율(MAX):  [1.5636997]
# # 24000  손실 비용:  2.3752964
# - 하수관로비율(MAX):  [1.545743]
# # 24500  손실 비용:  2.349566
# - 하수관로비율(MAX):  [1.5279584]
# # 25000  손실 비용:  2.3243206
# - 하수관로비율(MAX):  [1.5103446]
# # 25500  손실 비용:  2.2995615
# - 하수관로비율(MAX):  [1.4929076]
# # 26000  손실 비용:  2.2752745
# - 하수관로비율(MAX):  [1.4756411]
# # 26500  손실 비용:  2.2514453
# - 하수관로비율(MAX):  [1.4585409]
# # 27000  손실 비용:  2.2280638
# - 하수관로비율(MAX):  [1.4416054]
# # 27500  손실 비용:  2.2051227
# - 하수관로비율(MAX):  [1.4248309]
# # 28000  손실 비용:  2.1826117
# - 하수관로비율(MAX):  [1.4082175]
# # 28500  손실 비용:  2.1605222
# - 하수관로비율(MAX):  [1.3917621]
# # 29000  손실 비용:  2.1388545
# - 하수관로비율(MAX):  [1.375468]
# # 29500  손실 비용:  2.1176093
# - 하수관로비율(MAX):  [1.3593416]
# # 30000  손실 비용:  2.0967615
# - 하수관로비율(MAX):  [1.3433676]
# # 30500  손실 비용:  2.076303
# - 하수관로비율(MAX):  [1.3275449]
# # 31000  손실 비용:  2.0562253
# - 하수관로비율(MAX):  [1.3118724]
# # 31500  손실 비용:  2.0365212
# - 하수관로비율(MAX):  [1.2963455]
# # 32000  손실 비용:  2.0172133
# - 하수관로비율(MAX):  [1.2809877]
# # 32500  손실 비용:  1.9982651
# - 하수관로비율(MAX):  [1.265774]
# # 33000  손실 비용:  1.9796671
# - 하수관로비율(MAX):  [1.2507021]
# # 33500  손실 비용:  1.9614124
# - 하수관로비율(MAX):  [1.235771]
# # 34000  손실 비용:  1.9435134
# - 하수관로비율(MAX):  [1.2209911]
# # 34500  손실 비용:  1.9259613
# - 하수관로비율(MAX):  [1.2063617]
# # 35000  손실 비용:  1.9087313
# - 하수관로비율(MAX):  [1.1918666]
# # 35500  손실 비용:  1.8918164
# - 하수관로비율(MAX):  [1.1775041]
# # 36000  손실 비용:  1.875235
# - 하수관로비율(MAX):  [1.163292]
# # 36500  손실 비용:  1.858972
# - 하수관로비율(MAX):  [1.149221]
# # 37000  손실 비용:  1.8430045
# - 하수관로비율(MAX):  [1.135278]
# # 37500  손실 비용:  1.8273283
# - 하수관로비율(MAX):  [1.1214604]
# # 38000  손실 비용:  1.8119771
# - 하수관로비율(MAX):  [1.1078013]
# # 38500  손실 비용:  1.7969027
# - 하수관로비율(MAX):  [1.0942637]
# # 39000  손실 비용:  1.7821124
# - 하수관로비율(MAX):  [1.0808563]
# # 39500  손실 비용:  1.7675964
# - 하수관로비율(MAX):  [1.0675753]
# # 40000  손실 비용:  1.7533628
# - 하수관로비율(MAX):  [1.0544298]
# # 40500  손실 비용:  1.7393937
# - 하수관로비율(MAX):  [1.0414088]
# # 41000  손실 비용:  1.7256857
# - 하수관로비율(MAX):  [1.0285103]
# # 41500  손실 비용:  1.7122433
# - 하수관로비율(MAX):  [1.0157446]
# # 42000  손실 비용:  1.6990519
# - 하수관로비율(MAX):  [1.0030984]
# # 42500  손실 비용:  1.6861055
# - 하수관로비율(MAX):  [0.99057263]
# # 43000  손실 비용:  1.6734091
# - 하수관로비율(MAX):  [0.9781728]
# # 43500  손실 비용:  1.6609517
# - 하수관로비율(MAX):  [0.96589315]
# # 44000  손실 비용:  1.6487273
# - 하수관로비율(MAX):  [0.95373076]
# # 44500  손실 비용:  1.636732
# - 하수관로비율(MAX):  [0.941684]
# # 45000  손실 비용:  1.6249683
# - 하수관로비율(MAX):  [0.92976034]
# # 45500  손실 비용:  1.613426
# - 하수관로비율(MAX):  [0.9179507]
# # 46000  손실 비용:  1.6021001
# - 하수관로비율(MAX):  [0.9062553]
# # 46500  손실 비용:  1.5909861
# - 하수관로비율(MAX):  [0.89467055]
# # 47000  손실 비용:  1.5800809
# - 하수관로비율(MAX):  [0.8831991]
# # 47500  손실 비용:  1.5693873
# - 하수관로비율(MAX):  [0.8718429]
# # 48000  손실 비용:  1.5588939
# - 하수관로비율(MAX):  [0.86059725]
# # 48500  손실 비용:  1.5485977
# - 하수관로비율(MAX):  [0.8494583]
# # 49000  손실 비용:  1.5384951
# - 하수관로비율(MAX):  [0.8384288]
# # 49500  손실 비용:  1.5285828
# - 하수관로비율(MAX):  [0.827504]
# # 50000  손실 비용:  1.5188566
# - 하수관로비율(MAX):  [0.8166867]
# # 50500  손실 비용:  1.5093138
# - 하수관로비율(MAX):  [0.80597246]
# # 51000  손실 비용:  1.4999543
# - 하수관로비율(MAX):  [0.79536796]
# # 51500  손실 비용:  1.4907717
# - 하수관로비율(MAX):  [0.78486466]
# # 52000  손실 비용:  1.4817612
# - 하수관로비율(MAX):  [0.77446455]
# # 52500  손실 비용:  1.4729205
# - 하수관로비율(MAX):  [0.7641634]
# # 53000  손실 비용:  1.4642459
# - 하수관로비율(MAX):  [0.7539639]
# # 53500  손실 비용:  1.4557353
# - 하수관로비율(MAX):  [0.7438617]
# # 54000  손실 비용:  1.4473848
# - 하수관로비율(MAX):  [0.73385954]
# # 54500  손실 비용:  1.4391917
# - 하수관로비율(MAX):  [0.723953]
# # 55000  손실 비용:  1.4311537
# - 하수관로비율(MAX):  [0.7141448]
# # 55500  손실 비용:  1.4232671
# - 하수관로비율(MAX):  [0.7044307]
# # 56000  손실 비용:  1.4155289
# - 하수관로비율(MAX):  [0.6948123]
# # 56500  손실 비용:  1.4079369
# - 하수관로비율(MAX):  [0.68528694]
# # 57000  손실 비용:  1.4004883
# - 하수관로비율(MAX):  [0.6758553]
# # 57500  손실 비용:  1.3931798
# - 하수관로비율(MAX):  [0.66651493]
# # 58000  손실 비용:  1.3860091
# - 하수관로비율(MAX):  [0.6572659]
# # 58500  손실 비용:  1.3789734
# - 하수관로비율(MAX):  [0.6481066]
# # 59000  손실 비용:  1.3720698
# - 하수관로비율(MAX):  [0.639036]
# # 59500  손실 비용:  1.3652962
# - 하수관로비율(MAX):  [0.6300539]
# # 60000  손실 비용:  1.35865
# - 하수관로비율(MAX):  [0.62115777]
# # 60500  손실 비용:  1.3521273
# - 하수관로비율(MAX):  [0.6123486]
# # 61000  손실 비용:  1.3457308
# - 하수관로비율(MAX):  [0.6036271]
# # 61500  손실 비용:  1.3394557
# - 하수관로비율(MAX):  [0.59499425]
# # 62000  손실 비용:  1.3332987
# - 하수관로비율(MAX):  [0.58644307]
# # 62500  손실 비용:  1.3272563
# - 하수관로비율(MAX):  [0.57797503]
# # 63000  손실 비용:  1.321328
# - 하수관로비율(MAX):  [0.5695892]
# # 63500  손실 비용:  1.3155109
# - 하수관로비율(MAX):  [0.5612855]
# # 64000  손실 비용:  1.3098018
# - 하수관로비율(MAX):  [0.5530608]
# # 64500  손실 비용:  1.3041989
# - 하수관로비율(MAX):  [0.5449134]
# # 65000  손실 비용:  1.2987056
# - 하수관로비율(MAX):  [0.5368523]
# # 65500  손실 비용:  1.2933162
# - 하수관로비율(MAX):  [0.52887034]
# # 66000  손실 비용:  1.288027
# - 하수관로비율(MAX):  [0.52096415]
# # 66500  손실 비용:  1.2828373
# - 하수관로비율(MAX):  [0.51313597]
# # 67000  손실 비용:  1.2777424
# - 하수관로비율(MAX):  [0.5053799]
# # 67500  손실 비용:  1.2727433
# - 하수관로비율(MAX):  [0.4976996]
# # 68000  손실 비용:  1.2678437
# - 하수관로비율(MAX):  [0.4901019]
# # 68500  손실 비용:  1.2630342
# - 하수관로비율(MAX):  [0.48257527]
# # 69000  손실 비용:  1.258314
# - 하수관로비율(MAX):  [0.47512156]
# # 69500  손실 비용:  1.2536796
# - 하수관로비율(MAX):  [0.46773502]
# # 70000  손실 비용:  1.2491366
# - 하수관로비율(MAX):  [0.46042812]
# # 70500  손실 비용:  1.2446792
# - 하수관로비율(MAX):  [0.45319197]
# # 71000  손실 비용:  1.2403053
# - 하수관로비율(MAX):  [0.4460269]
# # 71500  손실 비용:  1.2360092
# - 하수관로비율(MAX):  [0.43892452]
# # 72000  손실 비용:  1.2317984
# - 하수관로비율(MAX):  [0.4318995]
# # 72500  손실 비용:  1.2276673
# - 하수관로비율(MAX):  [0.42494366]
# # 73000  손실 비용:  1.223612
# - 하수관로비율(MAX):  [0.4180526]
# # 73500  손실 비용:  1.219629
# - 하수관로비율(MAX):  [0.4112236]
# # 74000  손실 비용:  1.2157279
# - 하수관로비율(MAX):  [0.40447187]
# # 74500  손실 비용:  1.2118987
# - 하수관로비율(MAX):  [0.39778486]
# # 75000  손실 비용:  1.2081364
# - 하수관로비율(MAX):  [0.3911547]
# # 75500  손실 비용:  1.2044494
# - 하수관로비율(MAX):  [0.38459724]
# # 76000  손실 비용:  1.2008324
# - 하수관로비율(MAX):  [0.3781054]
# # 76500  손실 비용:  1.1972783
# - 하수관로비율(MAX):  [0.37166834]
# # 77000  손실 비용:  1.1937944
# - 하수관로비율(MAX):  [0.36530116]
# # 77500  손실 비용:  1.1903776
# - 하수관로비율(MAX):  [0.35899892]
# # 78000  손실 비용:  1.1870193
# - 하수관로비율(MAX):  [0.3527488]
# # 78500  손실 비용:  1.1837285
# - 하수관로비율(MAX):  [0.34656695]
# # 79000  손실 비용:  1.1805003
# - 하수관로비율(MAX):  [0.34044856]
# # 79500  손실 비용:  1.177327
# - 하수관로비율(MAX):  [0.3343795]
# # 80000  손실 비용:  1.1742191
# - 하수관로비율(MAX):  [0.32837975]
# # 80500  손실 비용:  1.1711675
# - 하수관로비율(MAX):  [0.32243657]
# # 81000  손실 비용:  1.1681699
# - 하수관로비율(MAX):  [0.3165464]
# # 81500  손실 비용:  1.1652354
# - 하수관로비율(MAX):  [0.31072494]
# # 82000  손실 비용:  1.1623492
# - 하수관로비율(MAX):  [0.30494922]
# # 82500  손실 비용:  1.1595201
# - 하수관로비율(MAX):  [0.29923508]
# # 83000  손실 비용:  1.1567454
# - 하수관로비율(MAX):  [0.29358068]
# # 83500  손실 비용:  1.1540177
# - 하수관로비율(MAX):  [0.28797218]
# # 84000  손실 비용:  1.1513485
# - 하수관로비율(MAX):  [0.2824325]
# # 84500  손실 비용:  1.1487219
# - 하수관로비율(MAX):  [0.27693385]
# # 85000  손실 비용:  1.1461499
# - 하수관로비율(MAX):  [0.27149844]
# # 85500  손실 비용:  1.1436229
# - 하수관로비율(MAX):  [0.26611093]
# # 86000  손실 비용:  1.1411433
# - 하수관로비율(MAX):  [0.26077658]
# # 86500  손실 비용:  1.1387131
# - 하수관로비율(MAX):  [0.25550088]
# # 87000  손실 비용:  1.1363232
# - 하수관로비율(MAX):  [0.25026682]
# # 87500  손실 비용:  1.1339846
# - 하수관로비율(MAX):  [0.24509774]
# # 88000  손실 비용:  1.1316814
# - 하수관로비율(MAX):  [0.23996286]
# # 88500  손실 비용:  1.1294309
# - 하수관로비율(MAX):  [0.23489702]
# # 89000  손실 비용:  1.1272141
# - 하수관로비율(MAX):  [0.22986458]
# # 89500  손실 비용:  1.1250453
# - 하수관로비율(MAX):  [0.22489585]
# # 90000  손실 비용:  1.1229112
# - 하수관로비율(MAX):  [0.21996328]
# # 90500  손실 비용:  1.1208223
# - 하수관로비율(MAX):  [0.21508995]
# # 91000  손실 비용:  1.1187677
# - 하수관로비율(MAX):  [0.21025571]
# # 91500  손실 비용:  1.1167556
# - 하수관로비율(MAX):  [0.20547676]
# # 92000  손실 비용:  1.1147773
# - 하수관로비율(MAX):  [0.20073745]
# # 92500  손실 비용:  1.1128395
# - 하수관로비율(MAX):  [0.19605285]
# # 93000  손실 비용:  1.1109339
# - 하수관로비율(MAX):  [0.19140579]
# # 93500  손실 비용:  1.109068
# - 하수관로비율(MAX):  [0.1868136]
# # 94000  손실 비용:  1.1072326
# - 하수관로비율(MAX):  [0.1822567]
# # 94500  손실 비용:  1.1054362
# - 하수관로비율(MAX):  [0.17775598]
# # 95000  손실 비용:  1.1036671
# - 하수관로비율(MAX):  [0.17328592]
# # 95500  손실 비용:  1.1019382
# - 하수관로비율(MAX):  [0.16887592]
# # 96000  손실 비용:  1.100233
# - 하수관로비율(MAX):  [0.16448951]
# # 96500  손실 비용:  1.0985693
# - 하수관로비율(MAX):  [0.16016908]
# # 97000  손실 비용:  1.0969275
# - 하수관로비율(MAX):  [0.15587075]
# # 97500  손실 비용:  1.0953242
# - 하수관로비율(MAX):  [0.15163308]
# # 98000  손실 비용:  1.0937456
# - 하수관로비율(MAX):  [0.1474261]
# # 98500  손실 비용:  1.0921992
# - 하수관로비율(MAX):  [0.14326668]
# # 99000  손실 비용:  1.0906804
# - 하수관로비율(MAX):  [0.13914648]
# # 99500  손실 비용:  1.0891881
# - 하수관로비율(MAX):  [0.13506143]
# # 100000  손실 비용:  1.0877272
# - 하수관로비율(MAX):  [0.13102661]

# %% [markdown]
# **학습 모델 저장**

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')

# 모델 저장을 위한 Saver 객체를 생성
# 학습된 모델을 저장
# 저장 완료 메시지를 출력
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# # [2] 다변인 선형회귀를 활용한 **하수관로 비율 예측**

# %% [markdown]
# **Base**

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정.
# 입력 데이터와 출력 데이터를 위한 TensorFlow placeholder를 생성.
# 입력 데이터는 [None, 2] 모양이고 출력 데이터는 [None, 1] 모양임.

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
#가중치와 편향 변수를 생성. 가중치의 모양은 [4, 1]이고 편향의 모양은 [1]

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 선형 회귀 모델의 가설을 설정
hypothesis = tf.matmul(X, W) + b

# %%
# TensorFlow 그래프와 세션 설정
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()

# 학습 모델 불러오기
save_path = "./saved.cpkt"
saver = tf.compat.v1.train.import_meta_graph(save_path + ".meta")
saver.restore(sess, save_path)

# 그래프로부터 텐서 가져오기
graph = tf.compat.v1.get_default_graph()
X = graph.get_tensor_by_name("X:0")  # Placeholder 이름 변경
hypothesis = graph.get_tensor_by_name("add:0")  # hypothesis 텐서 이름 변경

# %%
# 사용자로부터 강수량을 입력받습니다.

gradient = float(input('경사도(˚): '))
altitude = float(input('해발고도(m): '))
# Out:
# 경사도(˚): 20
# 해발고도(m): 30

# %%
# 입력 데이터를 준비
data = np.array([[gradient, altitude]], dtype=np.float32)

feed_dict = {X: data}
prediction = sess.run(hypothesis, feed_dict=feed_dict)

print("예측된 하수관로비율(MAX):", prediction[0][0])
# Out:
# 예측된 하수관로비율(MAX): -0.15409659
